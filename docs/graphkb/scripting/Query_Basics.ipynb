# %% [markdown]
# # Query Basics

# %% [markdown]
# <a href="https://colab.research.google.com/github/bcgsc/pori/blob/feature%2Fcolab-notebooks/docs/graphkb/scripting/Query_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Documentation for the API can be seen via its OpenAPI specification at [`/api/spec`](https://pori-demo.bcgsc.ca/graphkb-api/api/spec). Here we will cover just the query endpoint which is the most commonly used endpoint as it is used for all searches. The `/query` endpoint accepts a JSON body in a POST request. This is how the user passes filters and other search-related parameters. We will define a few of the important fields and concepts that are used below.
#
# All the running examples below use the python GraphKB adapter. This assumes the user has aready initialized the connector and logged in as shown below (using the demo database and credentials).
#
# First install the adapter

# %%
# %pip install pori_python
# Out:
# Requirement already satisfied: pori_python in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: biopython in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (1.85)
# Requirement already satisfied: jsonschema in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.25.1)
# Requirement already satisfied: pandas>=1.1.0 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (2.3.3)
# Requirement already satisfied: requests in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (2.32.5)
# Requirement already satisfied: tqdm in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.67.1)
# Requirement already satisfied: typing_extensions<5,>=3.7.4.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.15.0)
# Requirement already satisfied: numpy>=1.23.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas>=1.1.0->pori_python) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas>=1.1.0->pori_python) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas>=1.1.0->pori_python) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas>=1.1.0->pori_python) (2025.2)
# Requirement already satisfied: attrs>=22.2.0 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->pori_python) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then set up the connector

# %%
from pori_python.graphkb import GraphKBConnection
import os

GKB_API_URL = 'https://graphkbdev-api.bcgsc.ca/api' # 'https://pori-demo.bcgsc.ca/graphkb-api/api'
GKB_USER = os.environ.get('USER') # 'colab_demo'
GKB_PASSWORD = os.environ.get('JIRA_PASS') # 'colab_demo'

graphkb_conn = GraphKBConnection(GKB_API_URL)

graphkb_conn.login(GKB_USER, GKB_PASSWORD)

# %% [markdown]
# ## Important Fields and Concepts
#
# ### Query Target
#
# The target is the class/table that the users wishes to query. If it is at the top level of the request body then it is also the type of record which will be returned. For example to get a list of all publications in GraphKB. We limit this to the first 3 publications for the purposes of this demo

# %%
graphkb_conn.query({
    'target': 'Publication'
}, paginate=False, limit=3)
# Out:
# [{'@class': 'Publication',
#   'sourceId': '17768119',
#   'createdBy': '#29:0',
#   'createdAt': 1565627324756,
#   'journalName': 'haematologica',
#   'year': 2007,
#   'displayName': 'pmid:17768119',
#   'deprecated': False,
#   'name': 'clinical outcome of 27 imatinib mesylate-resistant chronic myelogenous leukemia patients harboring a t315i bcr-abl mutation.',
#   'source': '#40:2',
#   'uuid': '6e1166ae-fbf3-483b-99b2-9d9d4f478c34',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565627324756,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/17768119',
#   '@rid': '#117:0'},
#  {'@class': 'Publication',
#   'sourceId': '20619739',
#   'createdBy': '#29:0',
#   'createdAt': 1565627326845,
#   'journalName': 'the lancet. oncology',
#   'year': 2010,
#   'displayName': 'pmid:20619739',
#   'deprecated': False,
#   'name': 'effects of kras, braf, nras, and pik3ca mutations on the efficacy of cetuximab plus chemotherapy in chemotherapy-refractory metastatic colorectal cancer: a retrospective consortium analysis.',
#   'source': '#40:2',
#   'uuid': 'b6bcdfd1-c3dd-48eb-937b-ce6e543c76b3',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565627326845,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20619739',
#   '@rid': '#117:1'},
#  {'@class': 'Publication',
#   'sourceId': '24963404',
#   'createdBy': '#29:0',
#   'createdAt': 1565627327832,
#   'journalName': 'chemotherapy research and practice',
#   'year': 2014,
#   'displayName': 'pmid:24963404',
#   'deprecated': False,
#   'name': 'imatinib: a breakthrough of targeted therapy in cancer.',
#   'source': '#40:2',
#   'uuid': 'df32455e-a103-4bbd-be6f-b1ea9fd8d559',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565627327832,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24963404',
#   '@rid': '#117:2'}]

# %% [markdown]
# ### Filters
#
# Any field that is accessible with the current users permissions level can be queried via this endpoint. Most commonly users want to filter on this like a records name or source ID (ID in the external database it was imported from). Continuing our example from above let's search for publications with the word "cancer"  in them.
#
# **Note**: The current full text index only searches on word and word prefixes.

# %%
graphkb_conn.query({
    'target': 'Publication',
    'filters': {'name': 'cancer', 'operator': 'CONTAINSTEXT'}
}, paginate=False, limit=3)
# Out:
# [{'@class': 'Publication',
#   'sourceId': '23328547',
#   'createdBy': '#29:0',
#   'createdAt': 1565627325626,
#   'journalName': 'journal of thoracic oncology : official publication of the international association for the study of lung cancer',
#   'year': 2013,
#   'displayName': 'pmid:23328547',
#   'deprecated': False,
#   'name': 'natural history and molecular characteristics of lung cancers harboring egfr exon 20 insertions.',
#   'source': '#40:2',
#   'uuid': 'e2ef9eca-8875-4dfb-8e67-0d6d20614560',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565627325626,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23328547',
#   '@rid': '#119:0'},
#  {'@class': 'Publication',
#   'sourceId': '20530316',
#   'createdBy': '#29:0',
#   'createdAt': 1565629159422,
#   'journalName': 'the new england journal of medicine',
#   'year': 2010,
#   'displayName': 'pmid:20530316',
#   'deprecated': False,
#   'name': 'human papillomavirus and survival of patients with oropharyngeal cancer.',
#   'source': '#40:2',
#   'uuid': '2f29d745-f2dd-4f91-91bc-7fd0f9732bda',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565629159422,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20530316',
#   '@rid': '#119:289'},
#  {'@class': 'Publication',
#   'sourceId': '19223544',
#   'createdBy': '#29:0',
#   'createdAt': 1565629090224,
#   'journalName': 'cancer research',
#   'year': 2009,
#   'displayName': 'pmid:19223544',
#   'deprecated': False,
#   'name': 'pik3ca mutations in colorectal cancer are associated with clinical resistance to egfr-targeted monoclonal antibodies.',
#   'source': '#40:2',
#   'uuid': 'a1b4ee2b-bc5f-441b-82b9-2758cd32cf88',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565629090224,
#   'alias': False,
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19223544',
#   '@rid': '#119:278'}]

# %% [markdown]
# You can also filter on multiple conditions. To do this we nest filters in an object which uses a single AND/OR property with a list of regular conditions. For example if we want to find diseases with the name "cancer" or "carcinoma"

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'OR': [
            {'name': 'cancer'},
            {'name': 'carcinoma'},
        ]
    },
})
# Out:
# [{'@class': 'Disease',
#   'out_CrossReferenceOf': ['#74:29688', '#75:29664'],
#   'in_AliasOf': ['#67:5559', '#68:12561', '#67:58463'],
#   'out_ElementOf': [],
#   'createdBy': '#29:0',
#   'sourceId': 'doid:305',
#   'in_DeprecatedBy': ['#79:1348', '#77:2001'],
#   'displayName': 'carcinoma [DOID:305]',
#   'deprecated': False,
#   'description': 'a cell type cancer that has_material_basis_in abnormally proliferating cells derives_from epithelial cells.',
#   'source': '#38:2',
#   'uuid': '19e09fea-ca98-48e6-8c31-fc7c8e04e6cc',
#   'out_SubClassOf': ['#93:9006'],
#   'createdAt': 1565316918688,
#   'name': 'carcinoma',
#   'in_SubClassOf': [],
#   'subsets': ['doid#do_flybase_slim',
#    'doid#ncithesaurus',
#    'doid#do_cancer_slim'],
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316918688,
#   'alias': False,
#   '@rid': '#134:14635'},
#  {'@class': 'Disease',
#   'dependency': '#134:14635',
#   'createdBy': '#29:0',
#   'sourceId': 'doid:2428',
#   'createdAt': 1565316918717,
#   'displayName': 'carcinoma [DOID:2428]',
#   'deprecated': True,
#   'name': 'carcinoma',
#   'out_DeprecatedBy': ['#77:2001'],
#   'source': '#38:2',
#   'uuid': 'ceebca43-ab29-478a-9869-44af3bd36702',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316918717,
#   'alias': True,
#   '@rid': '#135:14635'},
#  {'@class': 'Disease',
#   'in_SubClassOf': [],
#   'out_SubClassOf': ['#93:22050', '#94:22062'],
#   'in_AliasOf': ['#68:8849',
#    '#66:15848',
#    '#67:22847',
#    '#66:1848',
#    '#65:8850',
#    '#67:15848',
#    '#68:22847',
#    '#67:1848',
#    '#66:67991'],
#   'createdAt': 1565315478822,
#   'displayName': 'Carcinoma [c2916]',
#   'sourceId': 'c2916',
#   'createdBy': '#29:0',
#   'deprecated': False,
#   'name': 'carcinoma',
#   'description': 'A malignant tumor arising from epithelial cells. Carcinomas that arise from glandular epithelium are called adenocarcinomas, those that arise from squamous epithelium are called squamous cell carcinomas, and those that arise from transitional epithelium are called transitional cell carcinomas. Morphologically, the malignant epithelial cells may display abnormal mitotic figures, anaplasia, and necrosis. Carcinomas are graded by the degree of cellular differentiation as well, moderately, or poorly differentiated. Carcinomas invade the surrounding tissues and tend to metastasize to other anatomic sites. Lung carcinoma, skin carcinoma, breast carcinoma, colon carcinoma, and prostate carcinoma are the most frequently seen carcinomas.',
#   'source': '#40:3',
#   'uuid': '1e4f77af-c4a1-488c-8e75-4edbcd03f4a9',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c2916',
#   'updatedBy': '#31:29',
#   'updatedAt': 1741142948544,
#   'alias': False,
#   'in_CrossReferenceOf': ['#74:29688'],
#   'history': '#134:37516',
#   '@rid': '#134:795'},
#  {'@class': 'Disease',
#   'dependency': '#134:14635',
#   'createdBy': '#29:0',
#   'sourceId': 'doid:6570',
#   'createdAt': 1565316918710,
#   'displayName': 'carcinoma [DOID:6570]',
#   'deprecated': True,
#   'name': 'carcinoma',
#   'out_DeprecatedBy': ['#79:1348'],
#   'source': '#38:2',
#   'uuid': 'c744ff2c-a3df-4056-b347-2437fdb2f398',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316918710,
#   'alias': True,
#   '@rid': '#135:9296'},
#  {'@class': 'Disease',
#   'deprecated': False,
#   'alias': False,
#   'name': 'cancer',
#   'displayName': 'cancer',
#   'source': '#37:1',
#   'sourceId': 'cancer_oncokb',
#   'createdBy': '#31:29',
#   'updatedBy': '#31:29',
#   'uuid': '78803f93-e6c7-48f8-9f7a-9a33308a6330',
#   'createdAt': 1750271230552,
#   'updatedAt': 1750271230552,
#   'out_CrossReferenceOf': ['#73:40034'],
#   'in_SubClassOf': ['#93:32284'],
#   '@rid': '#133:38508'},
#  {'@class': 'Disease',
#   'in_SubClassOf': ['#94:6260',
#    '#94:3929',
#    '#93:9330',
#    '#94:9327',
#    '#95:9328'],
#   'createdBy': '#29:0',
#   'out_ElementOf': [],
#   'sourceId': 'doid:162',
#   'in_AliasOf': ['#68:5708', '#65:12710', '#66:19710'],
#   'displayName': 'cancer [DOID:162]',
#   'deprecated': False,
#   'description': 'a disease of cellular proliferation that is malignant and primary, characterized by uncontrolled cellular proliferation, local cell invasion and metastasis.',
#   'source': '#38:2',
#   'uuid': '4ccd8528-5114-44dd-a313-ba044746da9a',
#   'out_SubClassOf': ['#95:8690'],
#   'createdAt': 1565316954360,
#   'name': 'cancer',
#   'subsets': ['doid#do_flybase_slim', 'doid#ncithesaurus', 'doid#do_agr_slim'],
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316954360,
#   'alias': False,
#   'out_CrossReferenceOf': ['#74:29732'],
#   '@rid': '#134:9542'},
#  {'@class': 'Disease',
#   'displayName': 'cancer [c9305]',
#   'sourceId': 'c9305',
#   'dependency': '#133:19222',
#   'createdBy': '#29:0',
#   'createdAt': 1565316035910,
#   'out_AliasOf': ['#65:4881'],
#   'deprecated': False,
#   'name': 'cancer',
#   'source': '#40:3',
#   'uuid': '276b6a65-5e80-4bd4-b7ca-7850bb5a9bfd',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316035910,
#   'alias': True,
#   'in_CrossReferenceOf': ['#73:40034'],
#   '@rid': '#136:3200'}]

# %% [markdown]
# The operator can be omitted here since `=` is the default operator. We can also combine conditions with `AND`

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'name': 'cancer', 'operator': 'CONTAINSTEXT'},
            {'name': 'pancreatic', 'operator': 'CONTAINSTEXT'},
        ]
    },
}, paginate=False, limit=3)
# Out:
# [{'@class': 'Disease',
#   'name': 'pancreatic cancer by ajcc v8 stage',
#   'displayName': 'pancreatic cancer by ajcc v8 stage [c134909]',
#   'sourceId': 'c134909',
#   'out_AliasOf': ['#65:800', '#67:34707'],
#   'dependency': '#136:11019',
#   'createdBy': '#29:0',
#   'createdAt': 1565315283877,
#   'deprecated': False,
#   'source': '#40:3',
#   'uuid': '6b294ab8-f41b-4bcc-8f54-35e3993b6361',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565315283877,
#   'alias': True,
#   '@rid': '#133:339'},
#  {'@class': 'Disease',
#   'name': 'pancreatic cancer stage iv',
#   'out_ElementOf': ['#84:96657',
#    '#83:99534',
#    '#81:130165',
#    '#83:131251',
#    '#84:131282',
#    '#84:134571',
#    '#81:137285',
#    '#83:137566',
#    '#81:138733',
#    '#84:138708',
#    '#84:144897',
#    '#83:145645',
#    '#83:148957',
#    '#81:219760',
#    '#83:224284'],
#   'displayName': 'pancreatic cancer stage iv [c5711]',
#   'sourceId': 'c5711',
#   'dependency': '#136:12534',
#   'createdBy': '#29:0',
#   'createdAt': 1565315668814,
#   'out_AliasOf': ['#66:9974'],
#   'deprecated': False,
#   'source': '#40:3',
#   'uuid': '03639c35-f4b4-421c-a3cb-f2e48509fb4d',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565315668814,
#   'alias': True,
#   '@rid': '#133:1854'},
#  {'@class': 'Disease',
#   'name': 'pancreatic cancer stage ii',
#   'displayName': 'pancreatic cancer stage ii [c7786]',
#   'sourceId': 'c7786',
#   'dependency': '#134:18570',
#   'out_ElementOf': ['#82:118212', '#82:124912'],
#   'createdBy': '#29:0',
#   'createdAt': 1565315871969,
#   'out_AliasOf': ['#66:24990'],
#   'deprecated': False,
#   'source': '#40:3',
#   'uuid': '497e540a-22f9-4157-ba7b-3c76345b1f0b',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565315871969,
#   'alias': True,
#   '@rid': '#133:2549'}]

# %% [markdown]
# The above will look for diseases that have both 'cancer' and 'pancreatic' in the name.

# %% [markdown]
# #### Subquery Filters
#
# Sometimes we would like to filter records on a linked field (essentially a foreign key). We can do this with subquery filters.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}
    },
}, paginate=False, limit=3)
# Out:
# [{'@class': 'Disease',
#   'dependency': '#134:14125',
#   'createdBy': '#29:0',
#   'sourceId': 'doid:11977',
#   'createdAt': 1565316842151,
#   'out_AliasOf': ['#65:19281'],
#   'displayName': 'disorder of magnesium metabolism [DOID:11977]',
#   'deprecated': False,
#   'name': 'disorder of magnesium metabolism',
#   'source': '#38:2',
#   'uuid': 'f456172e-8cb5-4051-8844-44c106231353',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316842151,
#   'alias': True,
#   '@rid': '#135:3444'},
#  {'@class': 'Disease',
#   'createdBy': '#29:0',
#   'sourceId': 'doid:7426',
#   'createdAt': 1565316845817,
#   'displayName': 'cutaneous anthrax [DOID:7426]',
#   'deprecated': False,
#   'name': 'cutaneous anthrax',
#   'description': 'an anthrax disease that results_in infection located_in skin, has_material_basis_in bacillus anthracis, which is transmitted_by contact with infected animals or animal products. the infection has_symptom skin lesion that eventually forms an ulcer with a black center.',
#   'source': '#38:2',
#   'out_SubClassOf': ['#96:3841', '#94:4028'],
#   'uuid': '3b473212-cd3e-4a33-a80f-cda7d2a78abf',
#   'subsets': ['doid#gram-positive_bacterial_infectious_disease',
#    'doid#zoonotic_infectious_disease'],
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316845817,
#   'alias': False,
#   '@rid': '#135:3467'},
#  {'@class': 'Disease',
#   'dependency': '#135:8799',
#   'createdBy': '#29:0',
#   'sourceId': 'doid:11949',
#   'createdAt': 1565316844209,
#   'out_AliasOf': ['#68:19288'],
#   'displayName': 'transmissible virus dementia [DOID:11949]',
#   'deprecated': False,
#   'name': 'transmissible virus dementia',
#   'source': '#38:2',
#   'uuid': '22bcaf64-1a14-4165-8364-5aec36f841de',
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316844209,
#   'alias': True,
#   '@rid': '#135:3457'}]

# %% [markdown]
# Above we are only returning disease records that have been imported from the disease ontology.

# %% [markdown]
# ### Return Properties (Fields)
#
# The return fields property allows the user to specify what they would like to return. This can mean returning a subset of fields for a large query to improve the speed of the client digesting the data, or it can be used to de-nest fields. By default the query will return only the immediate properties of the class being queries. This means that linked fields will be listed as their record ID. De-nesting these fields allows you to return them without additional queries.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
})
# Out:
# [{'@class': 'Disease',
#   'source': '#38:2',
#   'in_SubClassOf': ['#94:6260',
#    '#94:3929',
#    '#93:9330',
#    '#94:9327',
#    '#95:9328'],
#   'createdBy': '#29:0',
#   'out_ElementOf': [],
#   'sourceId': 'doid:162',
#   'in_AliasOf': ['#68:5708', '#65:12710', '#66:19710'],
#   'displayName': 'cancer [DOID:162]',
#   'deprecated': False,
#   'description': 'a disease of cellular proliferation that is malignant and primary, characterized by uncontrolled cellular proliferation, local cell invasion and metastasis.',
#   'uuid': '4ccd8528-5114-44dd-a313-ba044746da9a',
#   'out_SubClassOf': ['#95:8690'],
#   'createdAt': 1565316954360,
#   'name': 'cancer',
#   'subsets': ['doid#do_flybase_slim', 'doid#ncithesaurus', 'doid#do_agr_slim'],
#   'updatedBy': '#29:0',
#   'updatedAt': 1565316954360,
#   'alias': False,
#   'out_CrossReferenceOf': ['#74:29732'],
#   '@rid': '#134:9542'}]

# %% [markdown]
# We probably are not interested in all of these fields so let's pick a few to return.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
    'returnProperties': ['name', 'source', 'sourceId', 'alias', 'deprecated']
})
# Out:
# [{'alias': False,
#   'deprecated': False,
#   'name': 'cancer',
#   'source': '#38:2',
#   'sourceId': 'doid:162'}]

# %% [markdown]
# The new return looks much more reasonable. However the source field right now is a seperate record ID. This means with the current query we would have to fetch that record separately if we want to see details about it. This can be done in a single query with the nested return properties. Simply delimit properties and sub-properties with a period.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
    'returnProperties': ['name', 'source.name', 'sourceId', 'alias', 'deprecated']
})
# Out:
# [{'alias': False,
#   'deprecated': False,
#   'name': 'cancer',
#   'source': {'name': 'disease ontology'},
#   'sourceId': 'doid:162'}]
