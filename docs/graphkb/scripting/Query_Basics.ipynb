# %% [markdown]
# <a href="https://colab.research.google.com/github/bcgsc/pori/blob/feature%2Fcolab-notebooks/docs/graphkb/scripting/Query_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Query Basics

# %% [markdown]
# Documentation for the API can be seen via its OpenAPI specification at [`/api/spec`](https://pori-demo.bcgsc.ca/graphkb-api/api/spec). Here we will cover just the query endpoint which is the most commonly used endpoint as it is used for all searches. The `/query` endpoint accepts a JSON body in a POST request. This is how the user passes filters and other search-related parameters. We will defined a few of the important fields and concepts that are used below.
#
# All the running examples below use the python GraphKB adapter. This assumes the user has aready initialized the connector and logged in as shown below (using the demo database and credentials).
#
# First install the adapter

# %%
# !pip install graphkb
# Out:
# Collecting graphkb
#   Downloading graphkb-1.5.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests<3,>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from graphkb) (2.23.0)
# Requirement already satisfied: typing-extensions<4,>=3.7.4.2 in /usr/local/lib/python3.7/dist-packages (from graphkb) (3.7.4.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.22.0->graphkb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.22.0->graphkb) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.22.0->graphkb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.22.0->graphkb) (2.10)
# Installing collected packages: graphkb
# Successfully installed graphkb-1.5.4

# %% [markdown]
# Then set up the connector

# %%
from graphkb import GraphKBConnection

GKB_API_URL = 'https://pori-demo.bcgsc.ca/graphkb-api/api'
GKB_USER = 'colab_demo'
GKB_PASSWORD = 'colab_demo'

graphkb_conn = GraphKBConnection(GKB_API_URL)

graphkb_conn.login(GKB_USER, GKB_PASSWORD)

# %% [markdown]
# ## Important Fields and Concepts
#
# ### Query Target
#
# The target is the class/table that the users wishes to query. If it is at the top level of the request body then it is also the type of record which will be returned. For example to get a list of all publications in GraphKB. We limit this to the first 10 publications for the purposes of this demo

# %%
graphkb_conn.query({
    'target': 'Publication'
}, paginate=False, limit=10)
# Out:
# [{'@class': 'Publication',
#   '@rid': '#38:0',
#   'alias': False,
#   'createdAt': 1612980878029,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25500544',
#   'journalName': 'oncogene',
#   'name': 'the landscape and therapeutic relevance of cancer-associated transcript fusions.',
#   'source': '#17:21',
#   'sourceId': '25500544',
#   'updatedAt': 1612980878029,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25500544',
#   'uuid': '1294db97-ee26-4bd4-9b50-d122436905be',
#   'year': 2015},
#  {'@class': 'Publication',
#   '@rid': '#38:1',
#   'alias': False,
#   'createdAt': 1612981149054,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16081687',
#   'journalName': 'blood',
#   'name': 'the jak2v617f activating mutation occurs in chronic myelomonocytic leukemia and acute myeloid leukemia, but not in acute lymphoblastic leukemia or chronic lymphocytic leukemia.',
#   'source': '#17:21',
#   'sourceId': '16081687',
#   'updatedAt': 1612981149054,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16081687',
#   'uuid': '52e0d70f-07f8-48b9-b59d-b0258d60b9ae',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:2',
#   'alias': False,
#   'createdAt': 1612981150038,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15146165',
#   'journalName': 'laboratory investigation; a journal of technical methods and pathology',
#   'name': 'a great majority of gists with pdgfra mutations represent gastric tumors of low or no malignant potential.',
#   'source': '#17:21',
#   'sourceId': '15146165',
#   'updatedAt': 1612981150038,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15146165',
#   'uuid': '9e600c55-3247-4e24-bcd8-4a20bb0fb794',
#   'year': 2004},
#  {'@class': 'Publication',
#   '@rid': '#38:3',
#   'alias': False,
#   'createdAt': 1612981150922,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22081665',
#   'journalName': 'oncotarget',
#   'name': 'do aml patients with dnmt3a exon 23 mutations benefit from idarubicin as compared to daunorubicin? a single center experience.',
#   'source': '#17:21',
#   'sourceId': '22081665',
#   'updatedAt': 1612981150922,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22081665',
#   'uuid': '6c8fb887-9dee-467c-997e-6c320dde874b',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:4',
#   'alias': False,
#   'createdAt': 1612981151489,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22490330',
#   'journalName': 'blood',
#   'name': 'mutant dnmt3a: a marker of poor prognosis in acute myeloid leukemia.',
#   'source': '#17:21',
#   'sourceId': '22490330',
#   'updatedAt': 1612981151489,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22490330',
#   'uuid': '837d374c-b6c5-4a4e-a078-0d8733eeea09',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:5',
#   'alias': False,
#   'createdAt': 1612981152037,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19287384',
#   'journalName': 'nature genetics',
#   'name': 'a germline jak2 snp is associated with predisposition to the development of jak2(v617f)-positive myeloproliferative neoplasms.',
#   'source': '#17:21',
#   'sourceId': '19287384',
#   'updatedAt': 1612981152037,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19287384',
#   'uuid': '4b7541fa-0544-4c5b-af7e-b8c1babe88a7',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:6',
#   'alias': False,
#   'createdAt': 1612981152898,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24571676',
#   'journalName': 'bmc cancer',
#   'name': 'ras mutations in early age leukaemia modulated by nqo1 rs1800566 (c609t) are associated with second-hand smoking exposures.',
#   'source': '#17:21',
#   'sourceId': '24571676',
#   'updatedAt': 1612981152898,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24571676',
#   'uuid': 'f1655881-97c5-4f48-851e-0b564c433a28',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:7',
#   'alias': False,
#   'createdAt': 1612981153755,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23861977',
#   'journalName': 'plos one',
#   'name': 'nras and braf mutations in melanoma-associated nevi and uninvolved nevi.',
#   'source': '#17:21',
#   'sourceId': '23861977',
#   'updatedAt': 1612981153755,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23861977',
#   'uuid': 'c483b540-2f87-4071-925c-354caeb5fef1',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:8',
#   'alias': False,
#   'createdAt': 1612981154659,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19915144',
#   'journalName': 'proceedings of the national academy of sciences of the united states of america',
#   'name': 'mek1 mutations confer resistance to mek and b-raf inhibition.',
#   'source': '#17:21',
#   'sourceId': '19915144',
#   'updatedAt': 1612981154659,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19915144',
#   'uuid': 'ed5a9c65-6b1f-4593-85be-2624a73dc8b0',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:9',
#   'alias': False,
#   'createdAt': 1612981155387,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23569304',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'pharmacodynamic effects and mechanisms of resistance to vemurafenib in patients with metastatic melanoma.',
#   'source': '#17:21',
#   'sourceId': '23569304',
#   'updatedAt': 1612981155387,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23569304',
#   'uuid': '1762a178-6206-4043-a65c-c547a825e585',
#   'year': 2013}]

# %% [markdown]
# ### Filters
#
# Any field that is accessible with the current users permissions level can be queried via this endpoint. Most commonly users want to filter on this like a records name or source ID (ID in the external database it was imported from). Continuing our example from above let's search for publications with the word "cancer"  in them.
#
# **Note**: The current full text index only searches on word and word prefixes. Future iterations will support a full lucene index.

# %%
graphkb_conn.query({
    'target': 'Publication',
    'filters': {'name': 'cancer', 'operator': 'CONTAINSTEXT'}
})
# Out:
# [{'@class': 'Publication',
#   '@rid': '#38:0',
#   'alias': False,
#   'createdAt': 1612980878029,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25500544',
#   'journalName': 'oncogene',
#   'name': 'the landscape and therapeutic relevance of cancer-associated transcript fusions.',
#   'source': '#17:21',
#   'sourceId': '25500544',
#   'updatedAt': 1612980878029,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25500544',
#   'uuid': '1294db97-ee26-4bd4-9b50-d122436905be',
#   'year': 2015},
#  {'@class': 'Publication',
#   '@rid': '#38:19',
#   'alias': False,
#   'createdAt': 1612981162739,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24666267',
#   'journalName': 'acta oncologica (stockholm, sweden)',
#   'name': 'the predictive value of kras, nras, braf, pik3ca and pten for anti-egfr treatment in metastatic colorectal cancer: a systematic review and meta-analysis.',
#   'source': '#17:21',
#   'sourceId': '24666267',
#   'updatedAt': 1612981162739,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24666267',
#   'uuid': '06981f31-59d0-439e-b5cd-71f503f9c50e',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:22',
#   'alias': False,
#   'createdAt': 1612981164833,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21030459',
#   'journalName': 'cancer research',
#   'name': 'the neuroblastoma-associated f1174l alk mutation causes resistance to an alk kinase inhibitor in alk-translocated cancers.',
#   'source': '#17:21',
#   'sourceId': '21030459',
#   'updatedAt': 1612981164833,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21030459',
#   'uuid': '4f088978-1736-4e3e-83fb-6d2c70e88873',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:25',
#   'alias': False,
#   'createdAt': 1612981166942,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20619739',
#   'journalName': 'the lancet. oncology',
#   'name': 'effects of kras, braf, nras, and pik3ca mutations on the efficacy of cetuximab plus chemotherapy in chemotherapy-refractory metastatic colorectal cancer: a retrospective consortium analysis.',
#   'source': '#17:21',
#   'sourceId': '20619739',
#   'updatedAt': 1612981166942,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20619739',
#   'uuid': '6345dc8f-a6b3-4241-87c6-4fb37409b402',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:36',
#   'alias': False,
#   'createdAt': 1612981175007,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18073307',
#   'journalName': 'the journal of clinical endocrinology and metabolism',
#   'name': 'prognostic significance of somatic ret oncogene mutations in sporadic medullary thyroid cancer: a 10-year follow-up study.',
#   'source': '#17:21',
#   'sourceId': '18073307',
#   'updatedAt': 1612981175007,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18073307',
#   'uuid': '82456543-4b7c-412c-b151-b323146165ce',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:37',
#   'alias': False,
#   'createdAt': 1612981175518,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21422803',
#   'journalName': 'journal of endocrinological investigation',
#   'name': 'anti-tumor activity of motesanib in a medullary thyroid cancer model.',
#   'source': '#17:21',
#   'sourceId': '21422803',
#   'updatedAt': 1612981175518,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21422803',
#   'uuid': 'bcd12a07-967f-471b-9c32-852af8e6b29d',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:38',
#   'alias': False,
#   'createdAt': 1612981176064,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23056499',
#   'journalName': 'plos one',
#   'name': 'azd1480 blocks growth and tumorigenesis of ret- activated thyroid cancer cell lines.',
#   'source': '#17:21',
#   'sourceId': '23056499',
#   'updatedAt': 1612981176064,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23056499',
#   'uuid': 'eb10c823-5433-4212-9a48-20cc23bbb352',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:40',
#   'alias': False,
#   'createdAt': 1612981177589,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21594703',
#   'journalName': 'annals of surgical oncology',
#   'name': 'both braf v600e mutation and older age (≥ 65 years) are associated with recurrent papillary thyroid cancer.',
#   'source': '#17:21',
#   'sourceId': '21594703',
#   'updatedAt': 1612981177589,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21594703',
#   'uuid': 'a556bb4e-8479-4e0d-8826-1a31ab2826da',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:41',
#   'alias': False,
#   'createdAt': 1612981178109,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24570209',
#   'journalName': 'hormone and metabolic research = hormon- und stoffwechselforschung = hormones et metabolisme',
#   'name': 'immunohistochemistry for braf(v600e) antibody ve1 performed in core needle biopsy samples identifies mutated papillary thyroid cancers.',
#   'source': '#17:21',
#   'sourceId': '24570209',
#   'updatedAt': 1612981178109,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24570209',
#   'uuid': '6749cac6-a325-4f26-a86b-06cd0a0c9c08',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:42',
#   'alias': False,
#   'createdAt': 1612981178679,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23325582',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'massively parallel tumor multigene sequencing to evaluate response to panitumumab in a randomized phase iii study of metastatic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '23325582',
#   'updatedAt': 1612981178679,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23325582',
#   'uuid': '8e26adff-eff5-4c68-9d63-9c626ab73bce',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:43',
#   'alias': False,
#   'createdAt': 1612981179299,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19001320',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'wild-type braf is required for response to panitumumab or cetuximab in metastatic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '19001320',
#   'updatedAt': 1612981179299,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19001320',
#   'uuid': '714a1332-a0ea-4c4f-86a7-028a518a0c1c',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:45',
#   'alias': False,
#   'createdAt': 1612981180103,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23524406',
#   'journalName': 'journal of thoracic oncology : official publication of the international association for the study of lung cancer',
#   'name': 'molecular characterization of acquired resistance to the braf inhibitor dabrafenib in a patient with braf-mutant non-small-cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '23524406',
#   'updatedAt': 1612981180103,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23524406',
#   'uuid': '92269f30-42a6-421c-aee4-87efaa8db031',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:46',
#   'alias': False,
#   'createdAt': 1612981180725,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21098728',
#   'journalName': 'science signaling',
#   'name': 'braf gene amplification can promote acquired resistance to mek inhibitors in cancer cells harboring the braf v600e mutation.',
#   'source': '#17:21',
#   'sourceId': '21098728',
#   'updatedAt': 1612981180725,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21098728',
#   'uuid': '04df00f9-c607-4a4c-a5e1-a34dcb2b0d41',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:50',
#   'alias': False,
#   'createdAt': 1612981182953,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22180495',
#   'journalName': 'cancer research',
#   'name': 'antitumor activity of braf inhibitor vemurafenib in preclinical models of braf-mutant colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '22180495',
#   'updatedAt': 1612981182953,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22180495',
#   'uuid': '39b2de94-9dbf-4819-b5b8-e0efeb698fe9',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:51',
#   'alias': False,
#   'createdAt': 1612981183393,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24594804',
#   'journalName': 'plos one',
#   'name': 'brafv600e mutation and its association with clinicopathological features of colorectal cancer: a systematic review and meta-analysis.',
#   'source': '#17:21',
#   'sourceId': '24594804',
#   'updatedAt': 1612981183393,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24594804',
#   'uuid': '4bb232fd-d4f9-4ad9-8f17-70c64865f2f7',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:62',
#   'alias': False,
#   'createdAt': 1612981189624,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18202412',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'kras mutations as an independent prognostic factor in patients with advanced colorectal cancer treated with cetuximab.',
#   'source': '#17:21',
#   'sourceId': '18202412',
#   'updatedAt': 1612981189624,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18202412',
#   'uuid': '74b42cac-3bbe-40c8-b09c-d2a87767712b',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:63',
#   'alias': False,
#   'createdAt': 1612981190144,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20978259',
#   'journalName': 'jama',
#   'name': 'association of kras p.g13d mutation with outcome in patients with chemotherapy-refractory metastatic colorectal cancer treated with cetuximab.',
#   'source': '#17:21',
#   'sourceId': '20978259',
#   'updatedAt': 1612981190144,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20978259',
#   'uuid': '39db9b04-151d-4907-807e-cf17ab9f69ec',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:68',
#   'alias': False,
#   'createdAt': 1612981196440,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19966866',
#   'journalName': 'oncogene',
#   'name': 'tsc1 loss synergizes with kras activation in lung cancer development in the mouse and confers rapamycin sensitivity.',
#   'source': '#17:21',
#   'sourceId': '19966866',
#   'updatedAt': 1612981196440,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19966866',
#   'uuid': 'a826fbea-f835-44e0-8704-7cad209b7b94',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:77',
#   'alias': False,
#   'createdAt': 1612981201438,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20026798',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'favorable prognostic impact of npm1 mutations in older patients with cytogenetically normal de novo acute myeloid leukemia and associated gene- and microrna-expression signatures: a cancer and leukemia group b study.',
#   'source': '#17:21',
#   'sourceId': '20026798',
#   'updatedAt': 1612981201438,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20026798',
#   'uuid': '7dd1c4f3-fdb8-4a8b-88d8-a2acf24324e4',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:85',
#   'alias': False,
#   'createdAt': 1612981205502,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18559874',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': "wilms' tumor 1 gene mutations independently predict poor outcome in adults with cytogenetically normal acute myeloid leukemia: a cancer and leukemia group b study.",
#   'source': '#17:21',
#   'sourceId': '18559874',
#   'updatedAt': 1612981205502,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18559874',
#   'uuid': '880caa85-11fc-4082-90e5-73f2771c7299',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:86',
#   'alias': False,
#   'createdAt': 1612981206633,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23346317',
#   'journalName': 'journal of gynecologic oncology',
#   'name': 'advanced ovarian cancer: what should be the standard of care?',
#   'source': '#17:21',
#   'sourceId': '23346317',
#   'updatedAt': 1612981206633,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23346317',
#   'uuid': '1399961d-cf6e-4a32-af06-58d3d951df89',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:89',
#   'alias': False,
#   'createdAt': 1612981210456,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15961768',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'cyclin d1 in breast cancer pathogenesis.',
#   'source': '#17:21',
#   'sourceId': '15961768',
#   'updatedAt': 1612981210457,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15961768',
#   'uuid': '435bd53f-0ad0-4811-9399-eb4fd991bf68',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:94',
#   'alias': False,
#   'createdAt': 1612981213142,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23014527',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'molecular epidemiology of egfr and kras mutations in 3,026 lung adenocarcinomas: higher susceptibility of women to smoking-related kras-mutant cancers.',
#   'source': '#17:21',
#   'sourceId': '23014527',
#   'updatedAt': 1612981213142,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23014527',
#   'uuid': '004f3896-7dee-4fd0-8a7b-59db60519c93',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:95',
#   'alias': False,
#   'createdAt': 1612981214053,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24736073',
#   'journalName': 'journal of thoracic oncology : official publication of the international association for the study of lung cancer',
#   'name': 'comparison of clinical outcomes following gefitinib and erlotinib treatment in non-small-cell lung cancer patients harboring an epidermal growth factor receptor mutation in either exon 19 or 21.',
#   'source': '#17:21',
#   'sourceId': '24736073',
#   'updatedAt': 1612981214053,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24736073',
#   'uuid': 'cf6b40e2-a158-44e5-ada2-587befbb555c',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:98',
#   'alias': False,
#   'createdAt': 1612981215655,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20979473',
#   'journalName': 'the new england journal of medicine',
#   'name': 'eml4-alk mutations in lung cancer that confer resistance to alk inhibitors.',
#   'source': '#17:21',
#   'sourceId': '20979473',
#   'updatedAt': 1612981215655,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20979473',
#   'uuid': '9093f0a6-1aa1-4382-a0e7-6499f233fdd6',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:100',
#   'alias': False,
#   'createdAt': 1612981216514,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15728811',
#   'journalName': 'the new england journal of medicine',
#   'name': 'egfr mutation and resistance of non-small-cell lung cancer to gefitinib.',
#   'source': '#17:21',
#   'sourceId': '15728811',
#   'updatedAt': 1612981216514,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15728811',
#   'uuid': 'd6eccc87-6667-478d-8c6e-285787335c57',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:101',
#   'alias': False,
#   'createdAt': 1612981217028,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21430269',
#   'journalName': 'science translational medicine',
#   'name': 'genotypic and histological evolution of lung cancers acquiring resistance to egfr inhibitors.',
#   'source': '#17:21',
#   'sourceId': '21430269',
#   'updatedAt': 1612981217028,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21430269',
#   'uuid': 'b0fa6ba4-7831-4c7c-a244-65edc569c10b',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:102',
#   'alias': False,
#   'createdAt': 1612981217893,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23220880',
#   'journalName': 'cancer discovery',
#   'name': 'activating her2 mutations in her2 gene amplification negative breast cancer.',
#   'source': '#17:21',
#   'sourceId': '23220880',
#   'updatedAt': 1612981217893,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23220880',
#   'uuid': '35f31b17-b451-425f-a1ac-c35af6d94b0a',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:103',
#   'alias': False,
#   'createdAt': 1612981218958,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24185512',
#   'journalName': 'nature genetics',
#   'name': 'esr1 ligand-binding domain mutations in hormone-resistant breast cancer.',
#   'source': '#17:21',
#   'sourceId': '24185512',
#   'updatedAt': 1612981218958,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24185512',
#   'uuid': '28e0c25c-b731-4135-ad0d-353573a31201',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:106',
#   'alias': False,
#   'createdAt': 1612981221242,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16618717',
#   'journalName': 'cancer research',
#   'name': 'kras mutation status is predictive of response to cetuximab therapy in colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '16618717',
#   'updatedAt': 1612981221242,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16618717',
#   'uuid': '41e9898b-9432-4589-8325-e45dbb7f6d27',
#   'year': 2006},
#  {'@class': 'Publication',
#   '@rid': '#38:107',
#   'alias': False,
#   'createdAt': 1612981221674,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19794967',
#   'journalName': 'neoplasia (new york, n.y.)',
#   'name': 'clinical implications of kras mutations in lung cancer patients treated with tyrosine kinase inhibitors: an important role for mutations in minor clones.',
#   'source': '#17:21',
#   'sourceId': '19794967',
#   'updatedAt': 1612981221674,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19794967',
#   'uuid': '01a0ff56-711a-48f2-847f-896ce061e2b5',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:109',
#   'alias': False,
#   'createdAt': 1612981223546,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25002028',
#   'journalName': 'cancer cell',
#   'name': 'cdk 4/6 inhibitors sensitize pik3ca mutant breast cancer to pi3k inhibitors.',
#   'source': '#17:21',
#   'sourceId': '25002028',
#   'updatedAt': 1612981223546,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25002028',
#   'uuid': '2f94169f-8829-47a9-8950-d38d9350e61f',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:110',
#   'alias': False,
#   'createdAt': 1612981224359,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22328973',
#   'journalName': 'cancer discovery',
#   'name': 'mutations in the ddr2 kinase gene identify a novel therapeutic target in squamous cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '22328973',
#   'updatedAt': 1612981224359,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22328973',
#   'uuid': 'fa69ceb6-235e-4116-9310-6300750159fd',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:112',
#   'alias': False,
#   'createdAt': 1612981225891,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15118125',
#   'journalName': 'science (new york, n.y.)',
#   'name': 'egfr mutations in lung cancer: correlation with clinical response to gefitinib therapy.',
#   'source': '#17:21',
#   'sourceId': '15118125',
#   'updatedAt': 1612981225891,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15118125',
#   'uuid': 'b52691a0-4d22-476a-a3e7-897ee797f6c6',
#   'year': 2004},
#  {'@class': 'Publication',
#   '@rid': '#38:113',
#   'alias': False,
#   'createdAt': 1612981226291,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24457318',
#   'journalName': 'oncology',
#   'name': 'clinical predictors of response to egfr tyrosine kinase inhibitors in patients with egfr-mutant non-small cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '24457318',
#   'updatedAt': 1612981226291,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24457318',
#   'uuid': 'f8f5375c-0bf3-45af-b5c8-e042ac625d5b',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:115',
#   'alias': False,
#   'createdAt': 1612981227498,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24658966',
#   'journalName': 'amino acids',
#   'name': 'a systematic profile of clinical inhibitors responsive to egfr somatic amino acid mutations in lung cancer: implication for the molecular mechanism of drug resistance and sensitivity.',
#   'source': '#17:21',
#   'sourceId': '24658966',
#   'updatedAt': 1612981227498,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24658966',
#   'uuid': '76b63f4d-d39b-4cb6-b2e3-4d5683d77885',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:116',
#   'alias': False,
#   'createdAt': 1612981229062,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24185510',
#   'journalName': 'nature genetics',
#   'name': 'activating esr1 mutations in hormone-resistant metastatic breast cancer.',
#   'source': '#17:21',
#   'sourceId': '24185510',
#   'updatedAt': 1612981229062,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24185510',
#   'uuid': '64acde96-79fd-4066-aec6-cd017ab11ce9',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:120',
#   'alias': False,
#   'createdAt': 1612981234134,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22541434',
#   'journalName': 'cell',
#   'name': 'the gata2 transcriptional network is requisite for ras oncogene-driven non-small cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '22541434',
#   'updatedAt': 1612981234134,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22541434',
#   'uuid': '0451f8d8-d01e-4504-af75-0604cc76abdc',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:124',
#   'alias': False,
#   'createdAt': 1612981235879,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19029981',
#   'journalName': 'nature medicine',
#   'name': 'effective use of pi3k and mek inhibitors to treat mutant kras g12d and pik3ca h1047r murine lung cancers.',
#   'source': '#17:21',
#   'sourceId': '19029981',
#   'updatedAt': 1612981235879,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19029981',
#   'uuid': '26cad4c1-3a4b-464e-917e-6eef71cf75fe',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:126',
#   'alias': False,
#   'createdAt': 1612981237035,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21558396',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'the selective class i pi3k inhibitor ch5132799 targets human cancers harboring oncogenic pik3ca mutations.',
#   'source': '#17:21',
#   'sourceId': '21558396',
#   'updatedAt': 1612981237035,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21558396',
#   'uuid': 'ca43babe-e5c3-4581-909d-771f2d760d8a',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:127',
#   'alias': False,
#   'createdAt': 1612981237441,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15647370',
#   'journalName': 'proceedings of the national academy of sciences of the united states of america',
#   'name': 'phosphatidylinositol 3-kinase mutations identified in human cancer are oncogenic.',
#   'source': '#17:21',
#   'sourceId': '15647370',
#   'updatedAt': 1612981237441,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15647370',
#   'uuid': 'cf21810d-9987-455b-994f-a5e038667c1c',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:129',
#   'alias': False,
#   'createdAt': 1612981239786,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20085938',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'the pi3k pathway as drug target in human cancer.',
#   'source': '#17:21',
#   'sourceId': '20085938',
#   'updatedAt': 1612981239786,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20085938',
#   'uuid': '8b281fad-f8fc-4bdc-87d5-a813823bef56',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:130',
#   'alias': False,
#   'createdAt': 1612981240554,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22698404',
#   'journalName': 'cancer cell',
#   'name': 'p53-mediated senescence impairs the apoptotic response to chemotherapy and clinical outcome in breast cancer.',
#   'source': '#17:21',
#   'sourceId': '22698404',
#   'updatedAt': 1612981240554,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22698404',
#   'uuid': '2ed1bd16-6f12-4c3d-9fb9-20a1a82314fa',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:131',
#   'alias': False,
#   'createdAt': 1612981240997,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24662454',
#   'journalName': 'journal of thoracic oncology : official publication of the international association for the study of lung cancer',
#   'name': 'relationship between egfr expression, egfr mutation status, and the efficacy of chemotherapy plus cetuximab in flex study patients with advanced non-small-cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '24662454',
#   'updatedAt': 1612981240997,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24662454',
#   'uuid': 'e1ca6498-e607-4701-9d7c-187a7bb5fd29',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:136',
#   'alias': False,
#   'createdAt': 1612981244669,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:17070615',
#   'journalName': 'lung cancer (amsterdam, netherlands)',
#   'name': 'cyclin d1 in non-small cell lung cancer: a key driver of malignant transformation.',
#   'source': '#17:21',
#   'sourceId': '17070615',
#   'updatedAt': 1612981244669,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/17070615',
#   'uuid': 'ddaebfee-a08b-4384-961b-180e8841ac2c',
#   'year': 2007},
#  {'@class': 'Publication',
#   '@rid': '#38:139',
#   'alias': False,
#   'createdAt': 1612981246048,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:10547574',
#   'journalName': 'the journal of pathology',
#   'name': 'cyclin d2, but not cyclin d1, overexpression closely correlates with gastric cancer progression and prognosis.',
#   'source': '#17:21',
#   'sourceId': '10547574',
#   'updatedAt': 1612981246048,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/10547574',
#   'uuid': '68473ef3-758a-4d75-b458-9c72b62b97be',
#   'year': 1999},
#  {'@class': 'Publication',
#   '@rid': '#38:140',
#   'alias': False,
#   'createdAt': 1612981246915,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:12432043',
#   'journalName': 'the new england journal of medicine',
#   'name': 'cyclin e and survival in patients with breast cancer.',
#   'source': '#17:21',
#   'sourceId': '12432043',
#   'updatedAt': 1612981246915,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/12432043',
#   'uuid': '2657758e-2920-48ca-91b4-00292d7aef89',
#   'year': 2002},
#  {'@class': 'Publication',
#   '@rid': '#38:141',
#   'alias': False,
#   'createdAt': 1612981247313,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:10224221',
#   'journalName': 'faseb journal : official publication of the federation of american societies for experimental biology',
#   'name': 'cyclin e in human cancers.',
#   'source': '#17:21',
#   'sourceId': '10224221',
#   'updatedAt': 1612981247313,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/10224221',
#   'uuid': '7e98c0bd-8f83-4bbd-952b-6aabc2ffd3e4',
#   'year': 1999},
#  {'@class': 'Publication',
#   '@rid': '#38:142',
#   'alias': False,
#   'createdAt': 1612981248093,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23111194',
#   'journalName': 'diagnostic molecular pathology : the american journal of surgical pathology, part b',
#   'name': 'cdkn2a (p16) promoter hypermethylation influences the outcome in young lung cancer patients.',
#   'source': '#17:21',
#   'sourceId': '23111194',
#   'updatedAt': 1612981248093,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23111194',
#   'uuid': '65d2c856-58ef-4349-8511-6b41eb5cfc24',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:143',
#   'alias': False,
#   'createdAt': 1612981248495,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24623981',
#   'journalName': 'oncotargets and therapy',
#   'name': 'the predictive role of pretreatment epidermal growth factor receptor t790m mutation on the progression-free survival of tyrosine-kinase inhibitor-treated non-small cell lung cancer patients: a meta-analysis.',
#   'source': '#17:21',
#   'sourceId': '24623981',
#   'updatedAt': 1612981248495,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24623981',
#   'uuid': '98454bf7-6167-4dea-96d7-d39760d1f546',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:144',
#   'alias': False,
#   'createdAt': 1612981248894,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24729716',
#   'journalName': 'oncotargets and therapy',
#   'name': 'primary concomitant egfr t790m mutation predicted worse prognosis in non-small cell lung cancer patients.',
#   'source': '#17:21',
#   'sourceId': '24729716',
#   'updatedAt': 1612981248894,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24729716',
#   'uuid': 'a6b9ad7d-f2cc-41f3-a5f7-8e1a6b9978ae',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:145',
#   'alias': False,
#   'createdAt': 1612981249441,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:11585760',
#   'journalName': 'cancer research',
#   'name': 'absence of the wild-type allele predicts poor prognosis in adult de novo acute myeloid leukemia with normal cytogenetics and the internal tandem duplication of flt3: a cancer and leukemia group b study.',
#   'source': '#17:21',
#   'sourceId': '11585760',
#   'updatedAt': 1612981249441,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/11585760',
#   'uuid': '26f90613-af62-4a4a-b36f-f596afd72b7b',
#   'year': 2001},
#  {'@class': 'Publication',
#   '@rid': '#38:149',
#   'alias': False,
#   'createdAt': 1612981251254,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15597105',
#   'journalName': 'british journal of cancer',
#   'name': 'the role of ras oncogene in survival of patients with lung cancer: a systematic review of the literature with meta-analysis.',
#   'source': '#17:21',
#   'sourceId': '15597105',
#   'updatedAt': 1612981251254,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15597105',
#   'uuid': '1101faf8-cbaa-4b67-bf4d-6fe7859bba06',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:150',
#   'alias': False,
#   'createdAt': 1612981252091,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20007775',
#   'journalName': 'proceedings of the national academy of sciences of the united states of america',
#   'name': 'alterations of the notch pathway in lung cancer.',
#   'source': '#17:21',
#   'sourceId': '20007775',
#   'updatedAt': 1612981252091,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20007775',
#   'uuid': 'c3f467e4-386d-418d-9e1c-84ac4c761243',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:151',
#   'alias': False,
#   'createdAt': 1612981252764,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19223544',
#   'journalName': 'cancer research',
#   'name': 'pik3ca mutations in colorectal cancer are associated with clinical resistance to egfr-targeted monoclonal antibodies.',
#   'source': '#17:21',
#   'sourceId': '19223544',
#   'updatedAt': 1612981252764,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19223544',
#   'uuid': '3b0af8a8-e8cc-4d3f-87b4-5cadebbd2f6e',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:152',
#   'alias': False,
#   'createdAt': 1612981253374,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16489069',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'the clinical value of somatic tp53 gene mutations in 1,794 patients with breast cancer.',
#   'source': '#17:21',
#   'sourceId': '16489069',
#   'updatedAt': 1612981253374,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16489069',
#   'uuid': 'dfba08c1-c3b9-47e8-832d-81aaa8493bd3',
#   'year': 2006},
#  {'@class': 'Publication',
#   '@rid': '#38:153',
#   'alias': False,
#   'createdAt': 1612981253870,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:9569050',
#   'journalName': 'british journal of cancer',
#   'name': 'mutations in residues of tp53 that directly contact dna predict poor outcome in human primary breast cancer.',
#   'source': '#17:21',
#   'sourceId': '9569050',
#   'updatedAt': 1612981253870,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/9569050',
#   'uuid': '1d61a660-d669-45b0-9a37-4acf23b348b8',
#   'year': 1998},
#  {'@class': 'Publication',
#   '@rid': '#38:160',
#   'alias': False,
#   'createdAt': 1612981262635,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16818686',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'exon 19 deletion mutations of epidermal growth factor receptor are associated with prolonged survival in non-small cell lung cancer patients treated with gefitinib or erlotinib.',
#   'source': '#17:21',
#   'sourceId': '16818686',
#   'updatedAt': 1612981262635,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16818686',
#   'uuid': 'ac370478-0724-42fe-a30a-98156eeafb4d',
#   'year': 2006},
#  {'@class': 'Publication',
#   '@rid': '#38:161',
#   'alias': False,
#   'createdAt': 1612981263400,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25670080',
#   'journalName': 'cancer cell',
#   'name': 'a targetable gata2-igf2 axis confers aggressiveness in lethal prostate cancer.',
#   'source': '#17:21',
#   'sourceId': '25670080',
#   'updatedAt': 1612981263400,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25670080',
#   'uuid': '50575ac0-ac22-4713-ae13-3bec84e0cbf8',
#   'year': 2015},
#  {'@class': 'Publication',
#   '@rid': '#38:168',
#   'alias': False,
#   'createdAt': 1612981267772,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21343549',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'tet2 mutations improve the new european leukemianet risk classification of acute myeloid leukemia: a cancer and leukemia group b study.',
#   'source': '#17:21',
#   'sourceId': '21343549',
#   'updatedAt': 1612981267772,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21343549',
#   'uuid': '6f9fc819-a2b0-4cc2-b622-1d5929a9e05e',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:174',
#   'alias': False,
#   'createdAt': 1612981272136,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22277784',
#   'journalName': 'science translational medicine',
#   'name': 'mechanisms of acquired crizotinib resistance in alk-rearranged lung cancers.',
#   'source': '#17:21',
#   'sourceId': '22277784',
#   'updatedAt': 1612981272136,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22277784',
#   'uuid': '210311e7-81eb-4742-8709-a7f8864549de',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:186',
#   'alias': False,
#   'createdAt': 1612981280659,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15630448',
#   'journalName': 'the journal of clinical investigation',
#   'name': 'oncogenic akap9-braf fusion is a novel mechanism of mapk pathway activation in thyroid cancer.',
#   'source': '#17:21',
#   'sourceId': '15630448',
#   'updatedAt': 1612981280659,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15630448',
#   'uuid': '7f7e47cb-9504-4b0e-a23a-325a647a5614',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:188',
#   'alias': False,
#   'createdAt': 1612981281899,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22274685',
#   'journalName': 'jama',
#   'name': 'association between brca1 and brca2 mutations and survival in women with invasive epithelial ovarian cancer.',
#   'source': '#17:21',
#   'sourceId': '22274685',
#   'updatedAt': 1612981281899,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22274685',
#   'uuid': '01562a29-0e33-439a-8ce0-dbcaa08a5107',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:189',
#   'alias': False,
#   'createdAt': 1612981282393,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20336784',
#   'journalName': 'cancer',
#   'name': 'gene amplification ccne1 is related to poor survival and potential therapeutic target in ovarian cancer.',
#   'source': '#17:21',
#   'sourceId': '20336784',
#   'updatedAt': 1612981282393,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20336784',
#   'uuid': 'b31279d3-e49a-41a9-8402-1d5cb8fca975',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:195',
#   'alias': False,
#   'createdAt': 1612981284992,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:17538160',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'epidermal growth factor receptor copy number alterations correlate with poor clinical outcome in patients with head and neck squamous cancer.',
#   'source': '#17:21',
#   'sourceId': '17538160',
#   'updatedAt': 1612981284992,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/17538160',
#   'uuid': '27ca8edd-c429-4e63-8ed4-2a3b04c745c5',
#   'year': 2007},
#  {'@class': 'Publication',
#   '@rid': '#38:199',
#   'alias': False,
#   'createdAt': 1612981288913,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16254181',
#   'journalName': 'science (new york, n.y.)',
#   'name': 'recurrent fusion of tmprss2 and ets transcription factor genes in prostate cancer.',
#   'source': '#17:21',
#   'sourceId': '16254181',
#   'updatedAt': 1612981288913,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16254181',
#   'uuid': '37cdae4f-0885-496e-9c50-bf9079785db3',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:200',
#   'alias': False,
#   'createdAt': 1612981289261,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:20542753',
#   'journalName': 'cancer epidemiology',
#   'name': 'fgfr3 mutational status and protein expression in patients with bladder cancer in a jordanian population.',
#   'source': '#17:21',
#   'sourceId': '20542753',
#   'updatedAt': 1612981289261,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20542753',
#   'uuid': '6629c698-88bf-4365-b665-98ff77b0264d',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:206',
#   'alias': False,
#   'createdAt': 1612981293637,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23322234',
#   'journalName': 'breast cancer research and treatment',
#   'name': 'prognostic relevance of aib1 (ncoa3) amplification and overexpression in breast cancer.',
#   'source': '#17:21',
#   'sourceId': '23322234',
#   'updatedAt': 1612981293637,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23322234',
#   'uuid': 'bc046a15-fa21-4977-bb87-8e6701f8b7a9',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:211',
#   'alias': False,
#   'createdAt': 1612981297810,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16497822',
#   'journalName': 'annals of oncology : official journal of the european society for medical oncology',
#   'name': 'benefit from adjuvant tamoxifen therapy in primary breast cancer patients according oestrogen receptor, progesterone receptor, egf receptor and her2 status.',
#   'source': '#17:21',
#   'sourceId': '16497822',
#   'updatedAt': 1612981297810,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16497822',
#   'uuid': '958768ae-0f18-46e6-a7bc-75db423bab55',
#   'year': 2006},
#  {'@class': 'Publication',
#   '@rid': '#38:213',
#   'alias': False,
#   'createdAt': 1612981298667,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22292935',
#   'journalName': 'bmc cancer',
#   'name': 'highly frequent pik3ca amplification is associated with poor prognosis in gastric cancer.',
#   'source': '#17:21',
#   'sourceId': '22292935',
#   'updatedAt': 1612981298667,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22292935',
#   'uuid': 'eb43089f-a0bc-4687-bdf6-cd82a9d3b66b',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:214',
#   'alias': False,
#   'createdAt': 1612981299097,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:17700571',
#   'journalName': 'british journal of cancer',
#   'name': 'fish analysis of 107 prostate cancers shows that pten genomic deletion is associated with poor clinical outcome.',
#   'source': '#17:21',
#   'sourceId': '17700571',
#   'updatedAt': 1612981299097,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/17700571',
#   'uuid': 'c471e5ab-bea8-442c-9ffb-d159021555dc',
#   'year': 2007},
#  {'@class': 'Publication',
#   '@rid': '#38:215',
#   'alias': False,
#   'createdAt': 1612981299527,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21163703',
#   'journalName': 'the lancet. oncology',
#   'name': 'kras, braf, pik3ca, and pten mutations: implications for targeted therapies in metastatic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '21163703',
#   'updatedAt': 1612981299527,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21163703',
#   'uuid': '2ed8f43c-b043-475f-945e-65cd12cd942b',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:219',
#   'alias': False,
#   'createdAt': 1612981301610,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19584151',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'smad4 gene mutations are associated with poor prognosis in pancreatic cancer.',
#   'source': '#17:21',
#   'sourceId': '19584151',
#   'updatedAt': 1612981301610,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19584151',
#   'uuid': 'b66159d2-fce4-4b64-b8d4-0f3d7a921b46',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:224',
#   'alias': False,
#   'createdAt': 1612981304654,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22090360',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'tp53 disruptive mutations lead to head and neck cancer treatment failure through inhibition of radiation-induced senescence.',
#   'source': '#17:21',
#   'sourceId': '22090360',
#   'updatedAt': 1612981304654,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22090360',
#   'uuid': '8eeb146b-420a-4921-b149-00627d7a656c',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:230',
#   'alias': False,
#   'createdAt': 1612981307084,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:11248153',
#   'journalName': 'the new england journal of medicine',
#   'name': 'use of chemotherapy plus a monoclonal antibody against her2 for metastatic breast cancer that overexpresses her2.',
#   'source': '#17:21',
#   'sourceId': '11248153',
#   'updatedAt': 1612981307084,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/11248153',
#   'uuid': 'eb5d6cde-f86a-48b4-b564-cd587e8fb067',
#   'year': 2001},
#  {'@class': 'Publication',
#   '@rid': '#38:231',
#   'alias': False,
#   'createdAt': 1612981307458,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:15911866',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'randomized phase ii trial of the efficacy and safety of trastuzumab combined with docetaxel in patients with human epidermal growth factor receptor 2-positive metastatic breast cancer administered as first-line treatment: the m77001 study group.',
#   'source': '#17:21',
#   'sourceId': '15911866',
#   'updatedAt': 1612981307458,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/15911866',
#   'uuid': '4aa3168a-aae7-4789-ac63-0f05251c5805',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:248',
#   'alias': False,
#   'createdAt': 1612981316305,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23989949',
#   'journalName': 'british journal of cancer',
#   'name': 'pten deficiency is associated with reduced sensitivity to mtor inhibitor in human bladder cancer through the unhampered feedback loop driving pi3k/akt activation.',
#   'source': '#17:21',
#   'sourceId': '23989949',
#   'updatedAt': 1612981316305,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23989949',
#   'uuid': '43604d95-dc61-4c58-b1e9-c40516c1d163',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:249',
#   'alias': False,
#   'createdAt': 1612981316753,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24387334',
#   'journalName': 'current drug targets',
#   'name': 'therapeutic targeting of cancers with loss of pten function.',
#   'source': '#17:21',
#   'sourceId': '24387334',
#   'updatedAt': 1612981316753,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24387334',
#   'uuid': '07b9c312-5c28-4c85-9bb2-56b8e6bad874',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:250',
#   'alias': False,
#   'createdAt': 1612981317185,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25923550',
#   'journalName': 'the new england journal of medicine',
#   'name': 'rociletinib in egfr-mutated non-small-cell lung cancer.',
#   'source': '#17:21',
#   'sourceId': '25923550',
#   'updatedAt': 1612981317185,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25923550',
#   'uuid': '888ddfec-4388-4736-9ff9-a6188cc9b93e',
#   'year': 2015},
#  {'@class': 'Publication',
#   '@rid': '#38:251',
#   'alias': False,
#   'createdAt': 1612981317636,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:26510020',
#   'journalName': 'the new england journal of medicine',
#   'name': 'dna-repair defects and olaparib in metastatic prostate cancer.',
#   'source': '#17:21',
#   'sourceId': '26510020',
#   'updatedAt': 1612981317636,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/26510020',
#   'uuid': '13c4c855-b4db-4950-9c49-2c15630a8ecb',
#   'year': 2015},
#  {'@class': 'Publication',
#   '@rid': '#38:255',
#   'alias': False,
#   'createdAt': 1612981320293,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:25024077',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'braf v600e and tert promoter mutations cooperatively identify the most aggressive papillary thyroid cancer with highest recurrence.',
#   'source': '#17:21',
#   'sourceId': '25024077',
#   'updatedAt': 1612981320293,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/25024077',
#   'uuid': '094eb6b6-aded-41e0-9542-4840c0ba88d2',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:256',
#   'alias': False,
#   'createdAt': 1612981320799,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23766237',
#   'journalName': 'endocrine-related cancer',
# ...
#   'source': '#17:21',
#   'sourceId': '20736745',
#   'updatedAt': 1612986251478,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/20736745',
#   'uuid': '9af1e23b-59e4-40cf-80f5-4a981ffd590a',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:2123',
#   'alias': False,
#   'createdAt': 1612986251522,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18060073',
#   'journalName': 'plos one',
#   'name': 'mutation analysis of braf, mek1 and mek2 in 15 ovarian cancer cell lines: implications for therapy.',
#   'source': '#17:21',
#   'sourceId': '18060073',
#   'updatedAt': 1612986251522,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18060073',
#   'uuid': '047112a2-17aa-4477-a538-5fe785151e0d',
#   'year': 2007},
#  {'@class': 'Publication',
#   '@rid': '#38:2125',
#   'alias': False,
#   'createdAt': 1612986251651,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21829508',
#   'journalName': 'plos one',
#   'name': 'pik3ca mutations frequently coexist with ras and braf mutations in patients with advanced cancers.',
#   'source': '#17:21',
#   'sourceId': '21829508',
#   'updatedAt': 1612986251651,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21829508',
#   'uuid': '3c25b874-2792-45c4-a2a6-2b3f5861384e',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:2131',
#   'alias': False,
#   'createdAt': 1612986251719,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21479466',
#   'journalName': 'molecular medicine reports',
#   'name': 'akt1 and akt2 mutations in lung cancer in a japanese population.',
#   'source': '#17:21',
#   'sourceId': '21479466',
#   'updatedAt': 1612986251719,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21479466',
#   'uuid': '2637ad9f-dca8-4025-88da-de3fee991dd6',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:2132',
#   'alias': False,
#   'createdAt': 1612986251740,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:21984976',
#   'journalName': 'cancer discovery',
#   'name': 'high frequency of pik3r1 and pik3r2 mutations in endometrial cancer elucidates a novel mechanism for regulation of pten protein stability.',
#   'source': '#17:21',
#   'sourceId': '21984976',
#   'updatedAt': 1612986251740,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/21984976',
#   'uuid': '987b40cd-1e80-45c6-8dc0-bb204a8fb48b',
#   'year': 2011},
#  {'@class': 'Publication',
#   '@rid': '#38:2136',
#   'alias': False,
#   'createdAt': 1612986251747,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22898540',
#   'journalName': 'nature reviews. cancer',
#   'name': 'cancer stem cells: tracing clones.',
#   'source': '#17:21',
#   'sourceId': '22898540',
#   'updatedAt': 1612986251747,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22898540',
#   'uuid': '698d3f98-6c91-46a2-b2a8-9d03b0fb4712',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:2137',
#   'alias': False,
#   'createdAt': 1612986251747,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24657128',
#   'journalName': 'lung cancer (amsterdam, netherlands)',
#   'name': 'molecular profiling of small cell lung cancer in a japanese cohort.',
#   'source': '#17:21',
#   'sourceId': '24657128',
#   'updatedAt': 1612986251747,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24657128',
#   'uuid': '5c73dbf7-ad05-4029-93ff-41cc8db8f750',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2143',
#   'alias': False,
#   'createdAt': 1612986251766,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23406027',
#   'journalName': 'the new england journal of medicine',
#   'name': 'selumetinib-enhanced radioiodine uptake in advanced thyroid cancer.',
#   'source': '#17:21',
#   'sourceId': '23406027',
#   'updatedAt': 1612986251766,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23406027',
#   'uuid': 'dfd8532d-c521-427b-b115-2e3ac2a8aaf8',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:2146',
#   'alias': False,
#   'createdAt': 1612986251810,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24370118',
#   'journalName': 'clinical lung cancer',
#   'name': 'genetic mutation screen in early non--small-cell lung cancer (nsclc) specimens.',
#   'source': '#17:21',
#   'sourceId': '24370118',
#   'updatedAt': 1612986251810,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24370118',
#   'uuid': '7f90634e-87ae-47f9-adb2-8aafed22073c',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2147',
#   'alias': False,
#   'createdAt': 1612986251772,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24651012',
#   'journalName': 'cancer cell',
#   'name': 'mutant p53 in cancer: new functions and therapeutic opportunities.',
#   'source': '#17:21',
#   'sourceId': '24651012',
#   'updatedAt': 1612986251772,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24651012',
#   'uuid': 'd5fa11b6-55a2-4852-8eee-a227f4717c23',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2150',
#   'alias': False,
#   'createdAt': 1612986251863,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19946327',
#   'journalName': 'oncogene',
#   'name': 'the fgfr4 y367c mutant is a dominant oncogene in mda-mb453 breast cancer cells.',
#   'source': '#17:21',
#   'sourceId': '19946327',
#   'updatedAt': 1612986251863,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19946327',
#   'uuid': 'fefe724e-6e16-4767-ae5c-593836d706fa',
#   'year': 2010},
#  {'@class': 'Publication',
#   '@rid': '#38:2151',
#   'alias': False,
#   'createdAt': 1612986251870,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16043828',
#   'journalName': 'journal of clinical oncology : official journal of the american society of clinical oncology',
#   'name': 'mutations in the epidermal growth factor receptor and in kras are predictive and prognostic indicators in patients with non-small-cell lung cancer treated with chemotherapy alone and in combination with erlotinib.',
#   'source': '#17:21',
#   'sourceId': '16043828',
#   'updatedAt': 1612986251870,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16043828',
#   'uuid': 'fd77aadc-98d6-49c9-a464-a80b093e4e2c',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:2153',
#   'alias': False,
#   'createdAt': 1612986251874,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:16204070',
#   'journalName': 'cancer research',
#   'name': 'epidermal growth factor-independent transformation of ba/f3 cells with cancer-derived epidermal growth factor receptor mutants induces gefitinib-sensitive cell cycle progression.',
#   'source': '#17:21',
#   'sourceId': '16204070',
#   'updatedAt': 1612986251874,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/16204070',
#   'uuid': '4b84ae26-07e6-4bf2-af00-c4a62fcd7b4b',
#   'year': 2005},
#  {'@class': 'Publication',
#   '@rid': '#38:2163',
#   'alias': False,
#   'createdAt': 1612986251895,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22357840',
#   'journalName': 'clinical cancer research : an official journal of the american association for cancer research',
#   'name': 'prognostic role of pik3ca mutation in colorectal cancer: cohort study and literature review.',
#   'source': '#17:21',
#   'sourceId': '22357840',
#   'updatedAt': 1612986251895,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22357840',
#   'uuid': 'e9c69c9b-e831-4c88-a4fe-e69710a65772',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:2164',
#   'alias': False,
#   'createdAt': 1612986251895,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18992635',
#   'journalName': 'cancer genetics and cytogenetics',
#   'name': 'prevalence of mutations in apc, ctnnb1, and braf in tunisian patients with sporadic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '18992635',
#   'updatedAt': 1612986251895,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18992635',
#   'uuid': 'f91c6b9a-4587-40a8-b39e-f456761be331',
#   'year': 2008},
#  {'@class': 'Publication',
#   '@rid': '#38:2166',
#   'alias': False,
#   'createdAt': 1612986251903,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:22810696',
#   'journalName': 'nature',
#   'name': 'comprehensive molecular characterization of human colon and rectal cancer.',
#   'source': '#17:21',
#   'sourceId': '22810696',
#   'updatedAt': 1612986251903,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/22810696',
#   'uuid': 'dde17cbc-201b-48bf-a2fa-ad57707bdcbc',
#   'year': 2012},
#  {'@class': 'Publication',
#   '@rid': '#38:2172',
#   'alias': False,
#   'createdAt': 1612986251919,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24459181',
#   'journalName': 'cancer research',
#   'name': 'the structural basis of pi3k cancer mutations: from mechanism to therapy.',
#   'source': '#17:21',
#   'sourceId': '24459181',
#   'updatedAt': 1612986251919,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24459181',
#   'uuid': 'd5e13503-b469-490e-a350-9e86f801fd4c',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2174',
#   'alias': False,
#   'createdAt': 1612986251928,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19513541',
#   'journalName': 'international journal of molecular medicine',
#   'name': 'a novel dual pi3kalpha/mtor inhibitor pi-103 with high antitumor activity in non-small cell lung cancer cells.',
#   'source': '#17:21',
#   'sourceId': '19513541',
#   'updatedAt': 1612986251928,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19513541',
#   'uuid': 'f7da7eaf-0ae7-49a8-947e-7ad7bde7a8b4',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:2175',
#   'alias': False,
#   'createdAt': 1612986251923,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23408298',
#   'journalName': 'cancer',
#   'name': 'a phase 1 study of everolimus plus docetaxel plus cisplatin as induction chemotherapy for patients with locally and/or regionally advanced head and neck cancer.',
#   'source': '#17:21',
#   'sourceId': '23408298',
#   'updatedAt': 1612986251923,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23408298',
#   'uuid': '64279d84-b3e8-440e-a4ea-338097167b2a',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:2177',
#   'alias': False,
#   'createdAt': 1612986251937,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:11567109',
#   'journalName': 'science (new york, n.y.)',
#   'name': 'roots of clinical resistance to sti-571 cancer therapy.',
#   'source': '#17:21',
#   'sourceId': '11567109',
#   'updatedAt': 1612986251937,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/11567109',
#   'uuid': '56071d78-edbe-40ae-8207-874e55a1dade',
#   'year': 2001},
#  {'@class': 'Publication',
#   '@rid': '#38:2182',
#   'alias': False,
#   'createdAt': 1612986251975,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:11423618',
#   'journalName': 'science (new york, n.y.)',
#   'name': 'clinical resistance to sti-571 cancer therapy caused by bcr-abl gene mutation or amplification.',
#   'source': '#17:21',
#   'sourceId': '11423618',
#   'updatedAt': 1612986251975,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/11423618',
#   'uuid': '3122e51c-e56f-447c-9e27-af989770b24f',
#   'year': 2001},
#  {'@class': 'Publication',
#   '@rid': '#38:2191',
#   'alias': False,
#   'createdAt': 1612986252053,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23700467',
#   'journalName': 'plos one',
#   'name': 'targeted sequencing of cancer-related genes in colorectal cancer using next-generation sequencing.',
#   'source': '#17:21',
#   'sourceId': '23700467',
#   'updatedAt': 1612986252053,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23700467',
#   'uuid': '5a4f0b20-9a03-4377-8611-ccf95c75b72b',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:2194',
#   'alias': False,
#   'createdAt': 1612986253121,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24628546',
#   'journalName': 'the journal of clinical endocrinology and metabolism',
#   'name': 'development and characterization of a differentiated thyroid cancer cell line resistant to vegfr-targeted kinase inhibitors.',
#   'source': '#17:21',
#   'sourceId': '24628546',
#   'updatedAt': 1612986253121,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24628546',
#   'uuid': 'bd0b2572-3c8a-4864-8abf-688d2d9e0944',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2200',
#   'alias': False,
#   'createdAt': 1612986253203,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:12821112',
#   'journalName': 'biochemical and biophysical research communications',
#   'name': 'role of smad4 (dpc4) inactivation in human cancer.',
#   'source': '#17:21',
#   'sourceId': '12821112',
#   'updatedAt': 1612986253203,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/12821112',
#   'uuid': 'ac929622-239e-4a99-9ca4-4307d4b91e40',
#   'year': 2003},
#  {'@class': 'Publication',
#   '@rid': '#38:2206',
#   'alias': False,
#   'createdAt': 1612986257155,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:19487299',
#   'journalName': 'cancer research',
#   'name': 'mutational profile of advanced primary and metastatic radioactive iodine-refractory thyroid cancers reveals distinct pathogenetic roles for braf, pik3ca, and akt1.',
#   'source': '#17:21',
#   'sourceId': '19487299',
#   'updatedAt': 1612986257155,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/19487299',
#   'uuid': '25eb6654-6192-4435-9b09-1c9fc15f0db0',
#   'year': 2009},
#  {'@class': 'Publication',
#   '@rid': '#38:2211',
#   'alias': False,
#   'createdAt': 1612986257215,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:23728071',
#   'journalName': 'oncology reports',
#   'name': 'a detailed immunohistochemical analysis of the pi3k/akt/mtor pathway in lung cancer: correlation with pik3ca, akt1, k-ras or pten mutational status and clinicopathological features.',
#   'source': '#17:21',
#   'sourceId': '23728071',
#   'updatedAt': 1612986257215,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/23728071',
#   'uuid': '5570aabb-2b96-4dec-994a-8528889576e3',
#   'year': 2013},
#  {'@class': 'Publication',
#   '@rid': '#38:2220',
#   'alias': False,
#   'createdAt': 1612986265895,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24559322',
#   'journalName': 'expert review of anticancer therapy',
#   'name': 'regorafenib in metastatic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '24559322',
#   'updatedAt': 1612986265895,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24559322',
#   'uuid': '323a69a1-fab7-4eea-bb83-c36f1594e130',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2221',
#   'alias': False,
#   'createdAt': 1612986265900,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:24518971',
#   'journalName': 'cell journal',
#   'name': 'a unique profile of adenomatous polyposis coli gene mutations in iranian patients suffering sporadic colorectal cancer.',
#   'source': '#17:21',
#   'sourceId': '24518971',
#   'updatedAt': 1612986265900,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/24518971',
#   'uuid': '334eae3a-862c-4472-85de-b82e308736b8',
#   'year': 2014},
#  {'@class': 'Publication',
#   '@rid': '#38:2227',
#   'alias': False,
#   'createdAt': 1612986265967,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pmid:18186519',
#   'journalName': 'human mutation',
#   'name': 'rapid identification of somatic mutations in colorectal and breast cancer tissues using mismatch repair detection (mrd).',
#   'source': '#17:21',
#   'sourceId': '18186519',
#   'updatedAt': 1612986265967,
#   'updatedBy': '#14:0',
#   'url': 'https://pubmed.ncbi.nlm.nih.gov/18186519',
#   'uuid': '1fc4e897-b235-4c02-b8bc-bc872697432d',
#   'year': 2008}]

# %% [markdown]
# You can also filter on multiple conditions. To do this we nest filters in an object which uses a single AND/OR property with a list of regular conditions. For example if we want to find diseases with the name "cancer" or "carcinoma"

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'OR': [
            {'name': 'cancer'},
            {'name': 'carcinoma'},
        ]
    },
})
# Out:
# [{'@class': 'Disease',
#   '@rid': '#43:99077',
#   'alias': False,
#   'createdAt': 1612926192944,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'carcinoma',
#   'name': 'carcinoma',
#   'out_DeprecatedBy': ['#29:1400'],
#   'source': '#17:19',
#   'sourceId': 'doid:2428',
#   'updatedAt': 1612926192944,
#   'updatedBy': '#14:0',
#   'uuid': '2c61fd80-43fb-4cd2-941c-889a020cbbde'},
#  {'@class': 'Disease',
#   '@rid': '#43:99076',
#   'alias': False,
#   'createdAt': 1612926192912,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'carcinoma',
#   'name': 'carcinoma',
#   'out_DeprecatedBy': ['#29:1399'],
#   'source': '#17:19',
#   'sourceId': 'doid:6570',
#   'updatedAt': 1612926192912,
#   'updatedBy': '#14:0',
#   'uuid': 'baedee00-47a8-4d78-8ff5-7d9d8fadc03f'},
#  {'@class': 'Disease',
#   '@rid': '#43:99072',
#   'alias': False,
#   'createdAt': 1612926192816,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'A cell type cancer that has_material_basis_in abnormally proliferating cells derives_from epithelial cells.',
#   'displayName': 'carcinoma',
#   'history': '#43:107676',
#   'in_AliasOf': ['#26:160594', '#26:160595', '#26:160596'],
#   'in_DeprecatedBy': ['#29:1399', '#29:1400'],
#   'in_SubClassOf': [],
#   'name': 'carcinoma',
#   'out_CrossReferenceOf': ['#28:37788'],
#   'out_SubClassOf': ['#33:13951'],
#   'source': '#17:19',
#   'sourceId': 'doid:305',
#   'subsets': ['doid#do_flybase_slim',
#    'doid#ncithesaurus',
#    'doid#do_cancer_slim'],
#   'updatedAt': 1612980618003,
#   'updatedBy': '#14:0',
#   'uuid': '1775c2a3-b923-49f4-9e28-d5ccfcb32bc3'},
#  {'@class': 'Disease',
#   '@rid': '#43:68962',
#   'alias': True,
#   'createdAt': 1612863235878,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'cancer [c9305]',
#   'name': 'cancer',
#   'out_AliasOf': ['#26:137530'],
#   'source': '#17:0',
#   'sourceId': 'c9305',
#   'updatedAt': 1612863235878,
#   'updatedBy': '#14:0',
#   'uuid': 'ed0fffc2-31ef-435b-ae11-6efd6b193dd3'},
#  {'@class': 'Disease',
#   '@rid': '#43:100548',
#   'alias': False,
#   'createdAt': 1612926228848,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'A disease of cellular proliferation that is malignant and primary, characterized by uncontrolled cellular proliferation, local cell invasion and metastasis.',
#   'displayName': 'cancer',
#   'history': '#43:107678',
#   'in_AliasOf': ['#26:161531', '#26:161532', '#26:161533'],
#   'in_SubClassOf': ['#33:5210', '#33:5268'],
#   'name': 'cancer',
#   'out_CrossReferenceOf': ['#28:37957'],
#   'out_ElementOf': ['#30:82543'],
#   'out_SubClassOf': ['#33:7594'],
#   'source': '#17:19',
#   'sourceId': 'doid:162',
#   'subsets': ['doid#do_flybase_slim',
#    'doid#ncithesaurus',
#    'doid#do_cancer_slim',
#    'doid#do_agr_slim',
#    'doid#do_gxd_slim'],
#   'updatedAt': 1612980640268,
#   'updatedBy': '#14:0',
#   'uuid': '6a051270-4611-4af2-a5ff-1b31a872b4e0'}]

# %% [markdown]
# The operator can be omitted here since `=` is the default operator. We can also combined conditions with `AND`

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'name': 'cancer', 'operator': 'CONTAINSTEXT'},
            {'name': 'pancreatic', 'operator': 'CONTAINSTEXT'},
        ]
    },
})
# Out:
# [{'@class': 'Disease',
#   '@rid': '#43:1683',
#   'alias': True,
#   'createdAt': 1612854000193,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'recurrent pancreatic neuroendocrine cancer [c115433]',
#   'name': 'recurrent pancreatic neuroendocrine cancer',
#   'out_AliasOf': ['#26:5496'],
#   'source': '#17:0',
#   'sourceId': 'c115433',
#   'updatedAt': 1612854000193,
#   'updatedBy': '#14:0',
#   'uuid': 'a0831763-7bcb-4c68-a9dc-7aee6b3795c3'},
#  {'@class': 'Disease',
#   '@rid': '#43:8254',
#   'alias': True,
#   'createdAt': 1612855453528,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer by ajcc v6 and v7 stage [c134902]',
#   'name': 'pancreatic cancer by ajcc v6 and v7 stage',
#   'out_AliasOf': ['#26:18191'],
#   'source': '#17:0',
#   'sourceId': 'c134902',
#   'updatedAt': 1612855453528,
#   'updatedBy': '#14:0',
#   'uuid': '21e9a523-1982-4bf0-824d-c50bbe9b11b9'},
#  {'@class': 'Disease',
#   '@rid': '#43:8255',
#   'alias': True,
#   'createdAt': 1612855453548,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'exocrine and endocrine pancreatic cancer by ajcc v6 and v7 stage [c134902]',
#   'name': 'exocrine and endocrine pancreatic cancer by ajcc v6 and v7 stage',
#   'out_AliasOf': ['#26:18192'],
#   'source': '#17:0',
#   'sourceId': 'c134902',
#   'updatedAt': 1612855453548,
#   'updatedBy': '#14:0',
#   'uuid': 'd66fdfc2-578c-49cf-b3d7-cfe693fae104'},
#  {'@class': 'Disease',
#   '@rid': '#43:8259',
#   'alias': True,
#   'createdAt': 1612855453624,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer by ajcc v8 stage [c134909]',
#   'name': 'pancreatic cancer by ajcc v8 stage',
#   'out_AliasOf': ['#26:18195'],
#   'source': '#17:0',
#   'sourceId': 'c134909',
#   'updatedAt': 1612855453624,
#   'updatedBy': '#14:0',
#   'uuid': 'b8317e89-a42e-44cf-9ab6-7f6f1d58b615'},
#  {'@class': 'Disease',
#   '@rid': '#43:8260',
#   'alias': True,
#   'createdAt': 1612855453645,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'exocrine pancreatic cancer by ajcc v8 stage [c134909]',
#   'name': 'exocrine pancreatic cancer by ajcc v8 stage',
#   'out_AliasOf': ['#26:18196'],
#   'source': '#17:0',
#   'sourceId': 'c134909',
#   'updatedAt': 1612855453645,
#   'updatedBy': '#14:0',
#   'uuid': '3224e5c3-df93-4f6f-b1ff-623f5da9a0fe'},
#  {'@class': 'Disease',
#   '@rid': '#43:8263',
#   'alias': False,
#   'createdAt': 1612855453705,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage 0 includes: Tis, N0, M0. Tis: Carcinoma in situ. This includes high-grade pancreatic intraepithelial neoplasia (PanIn-3), intraductal papillary mucinous neoplasm with high-grade dysplasia, intraductal tubulopapillary neoplasm with high-grade dysplasia, and mucinous cystic neoplasm with high-grade dysplasia. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage 0 Pancreatic Cancer AJCC v8 [c134914]',
#   'in_AliasOf': ['#26:18199', '#26:18200', '#26:18201'],
#   'name': 'stage 0 pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134914',
#   'updatedAt': 1612855453705,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134914',
#   'uuid': '773197a4-bd68-40f8-836f-83aefb204f42'},
#  {'@class': 'Disease',
#   '@rid': '#43:8264',
#   'alias': True,
#   'createdAt': 1612855453718,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 exocrine pancreatic cancer ajcc v8 [c134914]',
#   'name': 'stage 0 exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18199'],
#   'source': '#17:0',
#   'sourceId': 'c134914',
#   'updatedAt': 1612855453718,
#   'updatedBy': '#14:0',
#   'uuid': 'a3c22592-d13b-43f2-ad95-b37ff2e06d64'},
#  {'@class': 'Disease',
#   '@rid': '#43:8266',
#   'alias': True,
#   'createdAt': 1612855453758,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 pancreatic cancer [c134914]',
#   'name': 'stage 0 pancreatic cancer',
#   'out_AliasOf': ['#26:18201'],
#   'source': '#17:0',
#   'sourceId': 'c134914',
#   'updatedAt': 1612855453758,
#   'updatedBy': '#14:0',
#   'uuid': 'aa9f0df4-2709-40ec-b668-ec197b8b4263'},
#  {'@class': 'Disease',
#   '@rid': '#43:8267',
#   'alias': False,
#   'createdAt': 1612855453777,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage I includes: IA: (T1, N0, M0); IB: (T2, N0, M0). T1: Tumor measuring 2 cm or less in greatest dimension. T2: Tumor measuring more than 2 cm and 4 cm or less in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage I Pancreatic Cancer AJCC v8 [c134915]',
#   'in_AliasOf': ['#26:18202', '#26:18203', '#26:18204'],
#   'name': 'stage i pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134915',
#   'updatedAt': 1612855453777,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134915',
#   'uuid': 'a9cb43c5-dc34-4417-aa19-86f94e572a20'},
#  {'@class': 'Disease',
#   '@rid': '#43:8268',
#   'alias': True,
#   'createdAt': 1612855453793,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i exocrine pancreatic cancer ajcc v8 [c134915]',
#   'name': 'stage i exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18202'],
#   'source': '#17:0',
#   'sourceId': 'c134915',
#   'updatedAt': 1612855453793,
#   'updatedBy': '#14:0',
#   'uuid': '36684e51-e96b-447c-959d-b5ad865e264a'},
#  {'@class': 'Disease',
#   '@rid': '#43:8270',
#   'alias': True,
#   'createdAt': 1612855453837,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i pancreatic cancer [c134915]',
#   'name': 'stage i pancreatic cancer',
#   'out_AliasOf': ['#26:18204'],
#   'source': '#17:0',
#   'sourceId': 'c134915',
#   'updatedAt': 1612855453837,
#   'updatedBy': '#14:0',
#   'uuid': '4817728a-82e7-4f87-aacf-9a5ba4efa732'},
#  {'@class': 'Disease',
#   '@rid': '#43:8271',
#   'alias': False,
#   'createdAt': 1612855453864,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IA includes: T1, N0, M0. T1: Tumor measuring 2 cm or less in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage IA Pancreatic Cancer AJCC v8 [c134917]',
#   'in_AliasOf': ['#26:18205', '#26:18206', '#26:18207', '#26:18208'],
#   'name': 'stage ia pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134917',
#   'updatedAt': 1612855453864,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134917',
#   'uuid': 'a17fbd1b-af7e-4d97-96cb-8d9577bbac6d'},
#  {'@class': 'Disease',
#   '@rid': '#43:8273',
#   'alias': True,
#   'createdAt': 1612855453896,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ia exocrine pancreatic cancer ajcc v8 [c134917]',
#   'name': 'stage ia exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18206'],
#   'source': '#17:0',
#   'sourceId': 'c134917',
#   'updatedAt': 1612855453896,
#   'updatedBy': '#14:0',
#   'uuid': '77760383-9581-4e5e-993d-ba79bf190de1'},
#  {'@class': 'Disease',
#   '@rid': '#43:8275',
#   'alias': True,
#   'createdAt': 1612855453937,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ia pancreatic cancer [c134917]',
#   'name': 'stage ia pancreatic cancer',
#   'out_AliasOf': ['#26:18208'],
#   'source': '#17:0',
#   'sourceId': 'c134917',
#   'updatedAt': 1612855453937,
#   'updatedBy': '#14:0',
#   'uuid': '3f6b9f4e-5e27-40ea-9c9f-779075045210'},
#  {'@class': 'Disease',
#   '@rid': '#43:8276',
#   'alias': False,
#   'createdAt': 1612855453957,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IB includes: T2, N0, M0. T2: Tumor measuring more than 2 cm and 4 cm or less in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage IB Pancreatic Cancer AJCC v8 [c134920]',
#   'in_AliasOf': ['#26:18209', '#26:18210', '#26:18211', '#26:18212'],
#   'name': 'stage ib pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134920',
#   'updatedAt': 1612855453957,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134920',
#   'uuid': '31803ce6-c88a-402d-b1b7-94b960c77abb'},
#  {'@class': 'Disease',
#   '@rid': '#43:8278',
#   'alias': True,
#   'createdAt': 1612855453990,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ib exocrine pancreatic cancer ajcc v8 [c134920]',
#   'name': 'stage ib exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18210'],
#   'source': '#17:0',
#   'sourceId': 'c134920',
#   'updatedAt': 1612855453990,
#   'updatedBy': '#14:0',
#   'uuid': 'c9d8a5f7-a313-414f-be13-1fa8ebbd6f6f'},
#  {'@class': 'Disease',
#   '@rid': '#43:8280',
#   'alias': True,
#   'createdAt': 1612855454030,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ib pancreatic cancer [c134920]',
#   'name': 'stage ib pancreatic cancer',
#   'out_AliasOf': ['#26:18212'],
#   'source': '#17:0',
#   'sourceId': 'c134920',
#   'updatedAt': 1612855454030,
#   'updatedBy': '#14:0',
#   'uuid': 'b2835313-872f-425c-9b63-dc1caf933fea'},
#  {'@class': 'Disease',
#   '@rid': '#43:8281',
#   'alias': False,
#   'createdAt': 1612855454049,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage II includes: IIA: (T3, N0, M0); IIB: (T1, N1, M0); (T2, N1, M0); (T3, N1, M0). T1: Tumor measuring 2 cm or less in greatest dimension. T2: Tumor measuring more than 2 cm and 4 cm or less in greatest dimension. T3: Tumor measuring more than 4 cm in greatest dimension. N0: No regional lymph node metastasis. N1: Metastasis in one to three regional lymph nodes. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage II Pancreatic Cancer AJCC v8 [c134921]',
#   'in_AliasOf': ['#26:18213', '#26:18214', '#26:18215'],
#   'name': 'stage ii pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134921',
#   'updatedAt': 1612855454049,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134921',
#   'uuid': '6c353bdf-3054-4623-897d-32805a1de01f'},
#  {'@class': 'Disease',
#   '@rid': '#43:8282',
#   'alias': True,
#   'createdAt': 1612855454062,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii exocrine pancreatic cancer ajcc v8 [c134921]',
#   'name': 'stage ii exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18213'],
#   'source': '#17:0',
#   'sourceId': 'c134921',
#   'updatedAt': 1612855454062,
#   'updatedBy': '#14:0',
#   'uuid': 'baf82288-696b-45b7-ab75-00d414b8db60'},
#  {'@class': 'Disease',
#   '@rid': '#43:8284',
#   'alias': True,
#   'createdAt': 1612855454100,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii pancreatic cancer [c134921]',
#   'name': 'stage ii pancreatic cancer',
#   'out_AliasOf': ['#26:18215'],
#   'source': '#17:0',
#   'sourceId': 'c134921',
#   'updatedAt': 1612855454100,
#   'updatedBy': '#14:0',
#   'uuid': '9038bd0d-876c-4e17-95bc-0fbab9f9c355'},
#  {'@class': 'Disease',
#   '@rid': '#43:8285',
#   'alias': False,
#   'createdAt': 1612855454119,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IIA includes: T3, N0, M0. T3: Tumor measuring more than 4 cm in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage IIA Pancreatic Cancer AJCC v8 [c134925]',
#   'in_AliasOf': ['#26:18216', '#26:18217', '#26:18218', '#26:18219'],
#   'name': 'stage iia pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134925',
#   'updatedAt': 1612855454119,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134925',
#   'uuid': 'ad5a6175-d855-472c-bf9d-8264de012115'},
#  {'@class': 'Disease',
#   '@rid': '#43:8287',
#   'alias': True,
#   'createdAt': 1612855454209,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iia exocrine pancreatic cancer ajcc v8 [c134925]',
#   'name': 'stage iia exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18217'],
#   'source': '#17:0',
#   'sourceId': 'c134925',
#   'updatedAt': 1612855454209,
#   'updatedBy': '#14:0',
#   'uuid': '844e8684-bc91-4960-9391-ec097cd69f01'},
#  {'@class': 'Disease',
#   '@rid': '#43:8289',
#   'alias': True,
#   'createdAt': 1612855454250,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iia pancreatic cancer [c134925]',
#   'name': 'stage iia pancreatic cancer',
#   'out_AliasOf': ['#26:18219'],
#   'source': '#17:0',
#   'sourceId': 'c134925',
#   'updatedAt': 1612855454250,
#   'updatedBy': '#14:0',
#   'uuid': '056b447e-a282-452a-9c8a-25a120629aa1'},
#  {'@class': 'Disease',
#   '@rid': '#43:8290',
#   'alias': False,
#   'createdAt': 1612855454271,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IIB includes: (T1, N1, M0); (T2, N1, M0); (T3, N1, M0). T1: Tumor measuring 2 cm or less in greatest dimension. T2: Tumor measuring more than 2 cm and 4 cm or less in greatest dimension. T3: Tumor measuring more than 4 cm in greatest dimension. N1: Metastasis in one to three regional lymph nodes. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage IIB Pancreatic Cancer AJCC v8 [c134927]',
#   'in_AliasOf': ['#26:18220', '#26:18221', '#26:18222', '#26:18223'],
#   'name': 'stage iib pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134927',
#   'updatedAt': 1612855454271,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134927',
#   'uuid': '1030ebb7-6f5f-40a7-9eb1-82f2a078ce62'},
#  {'@class': 'Disease',
#   '@rid': '#43:8292',
#   'alias': True,
#   'createdAt': 1612855454303,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iib exocrine pancreatic cancer ajcc v8 [c134927]',
#   'name': 'stage iib exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18221'],
#   'source': '#17:0',
#   'sourceId': 'c134927',
#   'updatedAt': 1612855454303,
#   'updatedBy': '#14:0',
#   'uuid': '14fa922b-a7d8-4998-bd3c-5d6ddbdcaeb6'},
#  {'@class': 'Disease',
#   '@rid': '#43:8294',
#   'alias': True,
#   'createdAt': 1612855454342,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iib pancreatic cancer [c134927]',
#   'name': 'stage iib pancreatic cancer',
#   'out_AliasOf': ['#26:18223'],
#   'source': '#17:0',
#   'sourceId': 'c134927',
#   'updatedAt': 1612855454342,
#   'updatedBy': '#14:0',
#   'uuid': '9ed3103a-f9d7-4495-ac45-140b1041340c'},
#  {'@class': 'Disease',
#   '@rid': '#43:8295',
#   'alias': False,
#   'createdAt': 1612855454362,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage III includes: (T1, N2, M0); (T2, N2, M0); (T3, N2, M0); (T4, Any N, M0). T1: Tumor measuring 2 cm or less in greatest dimension. T2: Tumor measuring more than 2 cm and 4 cm or less in greatest dimension. T3: Tumor measuring more than 4 cm in greatest dimension. T4: Tumor involving the celiac axis, superior mesenteric artery, and/or common hepatic artery, regardless of size. N2: Metastasis in four or more regional lymph nodes. M0: No distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage III Pancreatic Cancer AJCC v8 [c134928]',
#   'in_AliasOf': ['#26:18224', '#26:18225', '#26:18226', '#26:18227'],
#   'name': 'stage iii pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134928',
#   'updatedAt': 1612855454362,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134928',
#   'uuid': '5134adf4-1168-449b-aee0-3efe03b6a3b3'},
#  {'@class': 'Disease',
#   '@rid': '#43:8297',
#   'alias': True,
#   'createdAt': 1612855454402,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii exocrine pancreatic cancer ajcc v8 [c134928]',
#   'name': 'stage iii exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18225'],
#   'source': '#17:0',
#   'sourceId': 'c134928',
#   'updatedAt': 1612855454402,
#   'updatedBy': '#14:0',
#   'uuid': 'a0236a5a-4e40-4292-97db-40a83c00df5b'},
#  {'@class': 'Disease',
#   '@rid': '#43:8299',
#   'alias': True,
#   'createdAt': 1612855454449,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii pancreatic cancer [c134928]',
#   'name': 'stage iii pancreatic cancer',
#   'out_AliasOf': ['#26:18227'],
#   'source': '#17:0',
#   'sourceId': 'c134928',
#   'updatedAt': 1612855454449,
#   'updatedBy': '#14:0',
#   'uuid': 'cf52c186-d5c1-4b50-a347-6238ca4c5200'},
#  {'@class': 'Disease',
#   '@rid': '#43:8300',
#   'alias': False,
#   'createdAt': 1612855454469,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IV includes: Any T, Any N, M1. M1: Distant metastasis. (AJCC 8th ed.)',
#   'displayName': 'Stage IV Pancreatic Cancer AJCC v8 [c134930]',
#   'in_AliasOf': ['#26:18228', '#26:18229', '#26:18230', '#26:18231'],
#   'name': 'stage iv pancreatic cancer ajcc v8',
#   'source': '#17:0',
#   'sourceId': 'c134930',
#   'updatedAt': 1612855454469,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c134930',
#   'uuid': 'd11016c8-8f41-40dc-9c56-b8e24882ca92'},
#  {'@class': 'Disease',
#   '@rid': '#43:8302',
#   'alias': True,
#   'createdAt': 1612855454552,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv exocrine pancreatic cancer ajcc v8 [c134930]',
#   'name': 'stage iv exocrine pancreatic cancer ajcc v8',
#   'out_AliasOf': ['#26:18229'],
#   'source': '#17:0',
#   'sourceId': 'c134930',
#   'updatedAt': 1612855454552,
#   'updatedBy': '#14:0',
#   'uuid': '1dd34b7a-fcb3-4ff3-9d46-5f7e8d323826'},
#  {'@class': 'Disease',
#   '@rid': '#43:8304',
#   'alias': True,
#   'createdAt': 1612855454597,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv pancreatic cancer [c134930]',
#   'name': 'stage iv pancreatic cancer',
#   'out_AliasOf': ['#26:18231'],
#   'source': '#17:0',
#   'sourceId': 'c134930',
#   'updatedAt': 1612855454597,
#   'updatedBy': '#14:0',
#   'uuid': '0318ee85-d9d0-4d01-9d64-19ff07ef11bf'},
#  {'@class': 'Disease',
#   '@rid': '#43:9072',
#   'alias': True,
#   'createdAt': 1612855490364,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'refractory pancreatic neuroendocrine cancer [c137862]',
#   'name': 'refractory pancreatic neuroendocrine cancer',
#   'out_AliasOf': ['#26:19541'],
#   'source': '#17:0',
#   'sourceId': 'c137862',
#   'updatedAt': 1612855490364,
#   'updatedBy': '#14:0',
#   'uuid': '021268d2-84b6-4110-92d8-c4adfc483aef'},
#  {'@class': 'Disease',
#   '@rid': '#43:11384',
#   'alias': True,
#   'createdAt': 1612856094960,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'metastatic pancreatic neuroendocrine cancer [c153075]',
#   'name': 'metastatic pancreatic neuroendocrine cancer',
#   'out_AliasOf': ['#26:26884'],
#   'source': '#17:0',
#   'sourceId': 'c153075',
#   'updatedAt': 1612856094960,
#   'updatedBy': '#14:0',
#   'uuid': 'c3253b23-24c4-4af5-ae0a-3b3dd9a5da15'},
#  {'@class': 'Disease',
#   '@rid': '#43:11386',
#   'alias': True,
#   'createdAt': 1612856095076,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'unresectable pancreatic neuroendocrine cancer [c153079]',
#   'name': 'unresectable pancreatic neuroendocrine cancer',
#   'out_AliasOf': ['#26:26889'],
#   'source': '#17:0',
#   'sourceId': 'c153079',
#   'updatedAt': 1612856095076,
#   'updatedBy': '#14:0',
#   'uuid': '94604925-8027-40c6-ae69-e117b788d18f'},
#  {'@class': 'Disease',
#   '@rid': '#43:14127',
#   'alias': True,
#   'createdAt': 1612856623570,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreaticobiliary cancer [c166418]',
#   'name': 'pancreaticobiliary cancer',
#   'out_AliasOf': ['#26:37042'],
#   'source': '#17:0',
#   'sourceId': 'c166418',
#   'updatedAt': 1612856623570,
#   'updatedBy': '#14:0',
#   'uuid': '4367deae-82c1-4b67-9be5-c89513c3798f'},
#  {'@class': 'Disease',
#   '@rid': '#43:17122',
#   'alias': True,
#   'createdAt': 1612857298580,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'melanoma-pancreatic cancer syndrome [c176904]',
#   'name': 'melanoma-pancreatic cancer syndrome',
#   'out_AliasOf': ['#26:46184'],
#   'source': '#17:0',
#   'sourceId': 'c176904',
#   'updatedAt': 1612857298580,
#   'updatedBy': '#14:0',
#   'uuid': 'e2910a6f-4dfb-4ebf-9ef5-28e24c0606e7'},
#  {'@class': 'Disease',
#   '@rid': '#43:30363',
#   'alias': True,
#   'createdAt': 1612858805999,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic neuroendocrine cancer [c3770]',
#   'name': 'pancreatic neuroendocrine cancer',
#   'out_AliasOf': ['#26:68856'],
#   'source': '#17:0',
#   'sourceId': 'c3770',
#   'updatedAt': 1612858805999,
#   'updatedBy': '#14:0',
#   'uuid': '5233d0a4-4722-42ca-b45a-a5c57a7b9eb9'},
#  {'@class': 'Disease',
#   '@rid': '#43:30366',
#   'alias': True,
#   'createdAt': 1612858806075,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic endocrine cancer [c3770]',
#   'name': 'pancreatic endocrine cancer',
#   'out_AliasOf': ['#26:68859'],
#   'source': '#17:0',
#   'sourceId': 'c3770',
#   'updatedAt': 1612858806076,
#   'updatedBy': '#14:0',
#   'uuid': '2edd7d5d-dd05-4138-89f6-28f44689877e'},
#  {'@class': 'Disease',
#   '@rid': '#43:30862',
#   'alias': True,
#   'createdAt': 1612858821838,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer [c3850]',
#   'name': 'pancreatic cancer',
#   'out_AliasOf': ['#26:69449'],
#   'source': '#17:0',
#   'sourceId': 'c3850',
#   'updatedAt': 1612858821838,
#   'updatedBy': '#14:0',
#   'uuid': '243866b9-4b7c-4b4d-ae42-083e5ec0f02c'},
#  {'@class': 'Disease',
#   '@rid': '#43:30863',
#   'alias': True,
#   'createdAt': 1612858821858,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer (excluding islets), nos [c3850]',
#   'name': 'pancreatic cancer (excluding islets), nos',
#   'out_AliasOf': ['#26:69450'],
#   'source': '#17:0',
#   'sourceId': 'c3850',
#   'updatedAt': 1612858821858,
#   'updatedBy': '#14:0',
#   'uuid': 'dfb8ee5e-5f77-49d2-bc76-663adf1ec67b'},
#  {'@class': 'Disease',
#   '@rid': '#43:30864',
#   'alias': True,
#   'createdAt': 1612858821877,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer (not islets) [c3850]',
#   'name': 'pancreatic cancer (not islets)',
#   'out_AliasOf': ['#26:69451'],
#   'source': '#17:0',
#   'sourceId': 'c3850',
#   'updatedAt': 1612858821877,
#   'updatedBy': '#14:0',
#   'uuid': '98d9ccdc-b871-4c23-9664-bef4eacdfa6d'},
#  {'@class': 'Disease',
#   '@rid': '#43:34642',
#   'alias': True,
#   'createdAt': 1612859074428,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'familial pancreatic cancer [c43298]',
#   'name': 'familial pancreatic cancer',
#   'out_AliasOf': ['#26:73901'],
#   'source': '#17:0',
#   'sourceId': 'c43298',
#   'updatedAt': 1612859074428,
#   'updatedBy': '#14:0',
#   'uuid': '2bb6cfc5-0ad8-4b23-9764-8d0964e9666d'},
#  {'@class': 'Disease',
#   '@rid': '#43:34644',
#   'alias': True,
#   'createdAt': 1612859074465,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'familial pancreatic cancer syndrome [c43298]',
#   'name': 'familial pancreatic cancer syndrome',
#   'out_AliasOf': ['#26:73903'],
#   'source': '#17:0',
#   'sourceId': 'c43298',
#   'updatedAt': 1612859074465,
#   'updatedBy': '#14:0',
#   'uuid': '488074fb-f911-42d3-b079-3d0ce773adf0'},
#  {'@class': 'Disease',
#   '@rid': '#43:34645',
#   'alias': True,
#   'createdAt': 1612859074483,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'hereditary pancreatic cancer [c43298]',
#   'name': 'hereditary pancreatic cancer',
#   'out_AliasOf': ['#26:73904'],
#   'source': '#17:0',
#   'sourceId': 'c43298',
#   'updatedAt': 1612859074483,
#   'updatedBy': '#14:0',
#   'uuid': '85021b92-f1d1-479f-bb1b-e73c44c33f12'},
#  {'@class': 'Disease',
#   '@rid': '#43:39620',
#   'alias': True,
#   'createdAt': 1612859550528,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'unresectable pancreatic cancer [c5018]',
#   'name': 'unresectable pancreatic cancer',
#   'out_AliasOf': ['#26:82391'],
#   'source': '#17:0',
#   'sourceId': 'c5018',
#   'updatedAt': 1612859550528,
#   'updatedBy': '#14:0',
#   'uuid': 'e5dea52f-71c1-42bf-9bed-6af9c945fdb7'},
#  {'@class': 'Disease',
#   '@rid': '#43:40379',
#   'alias': True,
#   'createdAt': 1612859568876,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'resectable pancreatic cancer [c5099]',
#   'name': 'resectable pancreatic cancer',
#   'out_AliasOf': ['#26:83100'],
#   'source': '#17:0',
#   'sourceId': 'c5099',
#   'updatedAt': 1612859568876,
#   'updatedBy': '#14:0',
#   'uuid': '88df17b4-86ac-43a4-b12c-ef3a7b8a0646'},
#  {'@class': 'Disease',
#   '@rid': '#43:44334',
#   'alias': False,
#   'createdAt': 1612859943996,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IV includes: Any T, Any N, M1. M1: Distant metastasis. (AJCC 6th and 7th Eds.)',
#   'displayName': 'Stage IV Pancreatic Cancer AJCC v6 and v7 [c5711]',
#   'in_AliasOf': ['#26:87803',
#    '#26:87804',
#    '#26:87805',
#    '#26:87806',
#    '#26:87807',
#    '#26:87808',
#    '#26:87809',
#    '#26:87810'],
#   'name': 'stage iv pancreatic cancer ajcc v6 and v7',
#   'out_ElementOf': ['#30:82531'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859943996,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c5711',
#   'uuid': 'ce0260c1-c507-4031-b68f-2ba94efaecf2'},
#  {'@class': 'Disease',
#   '@rid': '#43:44335',
#   'alias': True,
#   'createdAt': 1612859944010,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer stage iv [c5711]',
#   'name': 'pancreatic cancer stage iv',
#   'out_AliasOf': ['#26:87803'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859944010,
#   'updatedBy': '#14:0',
#   'uuid': '2594e69a-8d4c-4b35-a71b-69b43072fd67'},
#  {'@class': 'Disease',
#   '@rid': '#43:44338',
#   'alias': True,
#   'createdAt': 1612859944145,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c5711]',
#   'name': 'stage iv exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:87806'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859944145,
#   'updatedBy': '#14:0',
#   'uuid': '0b61644c-2e8b-4c12-b878-d2440e83d9ec'},
#  {'@class': 'Disease',
#   '@rid': '#43:44339',
#   'alias': True,
#   'createdAt': 1612859944166,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv pancreatic cancer [c5711]',
#   'name': 'stage iv pancreatic cancer',
#   'out_AliasOf': ['#26:87807'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859944166,
#   'updatedBy': '#14:0',
#   'uuid': '91e78658-2dc3-4dee-a25c-96da6e25bf2b'},
#  {'@class': 'Disease',
#   '@rid': '#43:44340',
#   'alias': True,
#   'createdAt': 1612859944186,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv pancreatic cancer ajcc v6 [c5711]',
#   'name': 'stage iv pancreatic cancer ajcc v6',
#   'out_AliasOf': ['#26:87808'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859944186,
#   'updatedBy': '#14:0',
#   'uuid': '9ddc2bda-1e37-4e53-9666-961dadcf40e9'},
#  {'@class': 'Disease',
#   '@rid': '#43:44341',
#   'alias': True,
#   'createdAt': 1612859944206,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iv pancreatic cancer ajcc v7 [c5711]',
#   'name': 'stage iv pancreatic cancer ajcc v7',
#   'out_AliasOf': ['#26:87809'],
#   'source': '#17:0',
#   'sourceId': 'c5711',
#   'updatedAt': 1612859944206,
#   'updatedBy': '#14:0',
#   'uuid': '89f75c9a-4b09-42b0-9838-34e677302311'},
#  {'@class': 'Disease',
#   '@rid': '#43:44384',
#   'alias': True,
#   'createdAt': 1612859945137,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic adenosquamous cancer [c5721]',
#   'name': 'pancreatic adenosquamous cancer',
#   'out_AliasOf': ['#26:87845'],
#   'source': '#17:0',
#   'sourceId': 'c5721',
#   'updatedAt': 1612859945137,
#   'updatedBy': '#14:0',
#   'uuid': '172e9873-46bf-44b8-817c-d9296f687056'},
#  {'@class': 'Disease',
#   '@rid': '#43:44420',
#   'alias': False,
#   'createdAt': 1612859945857,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage 0 includes: Tis, N0, M0. Tis: Carcinoma in situ. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 6th and 7th Eds.)',
#   'displayName': 'Stage 0 Pancreatic Cancer AJCC v6 and v7 [c5729]',
#   'in_AliasOf': ['#26:87876',
#    '#26:87877',
#    '#26:87878',
#    '#26:87879',
#    '#26:87880',
#    '#26:87881',
#    '#26:87882',
#    '#26:87883',
#    '#26:87884',
#    '#26:87885'],
#   'name': 'stage 0 pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859945857,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c5729',
#   'uuid': '95092c66-6c89-43ea-a90c-4e1b0ffc947b'},
#  {'@class': 'Disease',
#   '@rid': '#43:44421',
#   'alias': True,
#   'createdAt': 1612859945907,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer stage 0 [c5729]',
#   'name': 'pancreatic cancer stage 0',
#   'out_AliasOf': ['#26:87876'],
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859945907,
#   'updatedBy': '#14:0',
#   'uuid': 'd2e5099a-223c-4927-89c8-54633226d192'},
#  {'@class': 'Disease',
#   '@rid': '#43:44425',
#   'alias': True,
#   'createdAt': 1612859945992,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c5729]',
#   'name': 'stage 0 exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:87880'],
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859945992,
#   'updatedBy': '#14:0',
#   'uuid': '279f1263-b333-4626-b923-0fce6c21ebe0'},
#  {'@class': 'Disease',
#   '@rid': '#43:44426',
#   'alias': True,
#   'createdAt': 1612859946014,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 pancreatic cancer [c5729]',
#   'name': 'stage 0 pancreatic cancer',
#   'out_AliasOf': ['#26:87881'],
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859946014,
#   'updatedBy': '#14:0',
#   'uuid': '1bf73f81-23fc-41ef-a8d5-d5eeca3686f8'},
#  {'@class': 'Disease',
#   '@rid': '#43:44427',
#   'alias': True,
#   'createdAt': 1612859946034,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 pancreatic cancer ajcc v6 [c5729]',
#   'name': 'stage 0 pancreatic cancer ajcc v6',
#   'out_AliasOf': ['#26:87882'],
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859946034,
#   'updatedBy': '#14:0',
#   'uuid': 'cf1e1291-3471-44bd-a967-b007f46b6138'},
#  {'@class': 'Disease',
#   '@rid': '#43:44428',
#   'alias': True,
#   'createdAt': 1612859946053,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage 0 pancreatic cancer ajcc v7 [c5729]',
#   'name': 'stage 0 pancreatic cancer ajcc v7',
#   'out_AliasOf': ['#26:87883'],
#   'source': '#17:0',
#   'sourceId': 'c5729',
#   'updatedAt': 1612859946053,
#   'updatedBy': '#14:0',
#   'uuid': '6c198324-4c96-4f62-b4d9-9b5d28534112'},
#  {'@class': 'Disease',
#   '@rid': '#43:56372',
#   'alias': True,
#   'createdAt': 1612861597316,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'recurrent pancreatic cancer [c7626]',
#   'name': 'recurrent pancreatic cancer',
#   'out_AliasOf': ['#26:113659'],
#   'source': '#17:0',
#   'sourceId': 'c7626',
#   'updatedAt': 1612861597316,
#   'updatedBy': '#14:0',
#   'uuid': '9239d11e-4756-4e1e-a900-68db24e72c17'},
#  {'@class': 'Disease',
#   '@rid': '#43:56377',
#   'alias': True,
#   'createdAt': 1612861597411,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'relapsed pancreatic cancer [c7626]',
#   'name': 'relapsed pancreatic cancer',
#   'out_AliasOf': ['#26:113664'],
#   'source': '#17:0',
#   'sourceId': 'c7626',
#   'updatedAt': 1612861597411,
#   'updatedBy': '#14:0',
#   'uuid': 'f5b9557b-bcd2-49ed-b953-1cb201cd4d79'},
#  {'@class': 'Disease',
#   '@rid': '#43:57138',
#   'alias': False,
#   'createdAt': 1612861827869,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage I includes: IA (T1, N0, M0); IB (T2, N0, M0). T1: Tumor limited to the pancreas 2 cm or less in greatest dimension. T2: Tumor limited to the pancreas, more than 2 cm in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (AJCC 6th and 7th Eds.)',
#   'displayName': 'Stage I Pancreatic Cancer AJCC v6 and v7 [c7785]',
#   'in_AliasOf': ['#26:116742',
#    '#26:116743',
#    '#26:116744',
#    '#26:116745',
#    '#26:116746',
#    '#26:116747',
#    '#26:116748',
#    '#26:116749'],
#   'name': 'stage i pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827869,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c7785',
#   'uuid': '89ec72ac-6a95-4879-838f-a2cae0213205'},
#  {'@class': 'Disease',
#   '@rid': '#43:57139',
#   'alias': True,
#   'createdAt': 1612861827881,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer stage i [c7785]',
#   'name': 'pancreatic cancer stage i',
#   'out_AliasOf': ['#26:116742'],
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827881,
#   'updatedBy': '#14:0',
#   'uuid': '6c0dbde2-6d06-4b5a-8894-39175ee990b1'},
#  {'@class': 'Disease',
#   '@rid': '#43:57142',
#   'alias': True,
#   'createdAt': 1612861827938,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c7785]',
#   'name': 'stage i exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:116745'],
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827938,
#   'updatedBy': '#14:0',
#   'uuid': '93007b66-4f7f-45b8-b0dd-915f32cec8fa'},
#  {'@class': 'Disease',
#   '@rid': '#43:57143',
#   'alias': True,
#   'createdAt': 1612861827960,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i pancreatic cancer [c7785]',
#   'name': 'stage i pancreatic cancer',
#   'out_AliasOf': ['#26:116746'],
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827960,
#   'updatedBy': '#14:0',
#   'uuid': '347f769d-6b46-4abb-90df-0887fb032e81'},
#  {'@class': 'Disease',
#   '@rid': '#43:57144',
#   'alias': True,
#   'createdAt': 1612861827980,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i pancreatic cancer ajcc v6 [c7785]',
#   'name': 'stage i pancreatic cancer ajcc v6',
#   'out_AliasOf': ['#26:116747'],
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827980,
#   'updatedBy': '#14:0',
#   'uuid': '226e6a14-b8de-4cce-bef5-d2ed2cd889c7'},
#  {'@class': 'Disease',
#   '@rid': '#43:57145',
#   'alias': True,
#   'createdAt': 1612861827999,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage i pancreatic cancer ajcc v7 [c7785]',
#   'name': 'stage i pancreatic cancer ajcc v7',
#   'out_AliasOf': ['#26:116748'],
#   'source': '#17:0',
#   'sourceId': 'c7785',
#   'updatedAt': 1612861827999,
#   'updatedBy': '#14:0',
#   'uuid': '14d97e5f-a141-4b09-98d0-4146f0fd0703'},
#  {'@class': 'Disease',
#   '@rid': '#43:57147',
#   'alias': False,
#   'createdAt': 1612861828749,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage II includes: IIA (T3, N0, M0); IIB (T1, N1, M0); (T2, N1, M0); (T3, N1, M0). T1: Tumor limited to the pancreas 2 cm or less in greatest dimension. T2: Tumor limited to the pancreas, more than 2 cm in greatest dimension. T3: Tumor extends beyond the pancreas but without involvement of the celiac axis or the superior mesenteric artery. N0: No regional lymph node metastasis. N1: Regional lymph node metastasis. M0: No distant metastasis. (AJCC 6th and 7th Eds.)',
#   'displayName': 'Stage II Pancreatic Cancer AJCC v6 and v7 [c7786]',
#   'in_AliasOf': ['#26:116771',
#    '#26:116772',
#    '#26:116773',
#    '#26:116774',
#    '#26:116775',
#    '#26:116776',
#    '#26:116777',
#    '#26:116778'],
#   'name': 'stage ii pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828749,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c7786',
#   'uuid': '98007027-7e36-4e15-99f4-944805ea1034'},
#  {'@class': 'Disease',
#   '@rid': '#43:57148',
#   'alias': True,
#   'createdAt': 1612861828763,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer stage ii [c7786]',
#   'name': 'pancreatic cancer stage ii',
#   'out_AliasOf': ['#26:116771'],
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828763,
#   'updatedBy': '#14:0',
#   'uuid': 'ec0c5416-dd72-4acb-9f2c-de7661fe756e'},
#  {'@class': 'Disease',
#   '@rid': '#43:57151',
#   'alias': True,
#   'createdAt': 1612861828819,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c7786]',
#   'name': 'stage ii exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:116774'],
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828819,
#   'updatedBy': '#14:0',
#   'uuid': 'abe73ca6-125e-432e-8b9a-1ec08701a81a'},
#  {'@class': 'Disease',
#   '@rid': '#43:57152',
#   'alias': True,
#   'createdAt': 1612861828838,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii pancreatic cancer [c7786]',
#   'name': 'stage ii pancreatic cancer',
#   'out_AliasOf': ['#26:116775'],
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828838,
#   'updatedBy': '#14:0',
#   'uuid': 'aaab8221-2294-4ba3-b4db-6d84968e8dea'},
#  {'@class': 'Disease',
#   '@rid': '#43:57153',
#   'alias': True,
#   'createdAt': 1612861828857,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii pancreatic cancer ajcc v6 [c7786]',
#   'name': 'stage ii pancreatic cancer ajcc v6',
#   'out_AliasOf': ['#26:116776'],
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828857,
#   'updatedBy': '#14:0',
#   'uuid': '0e565e1a-09fd-49b0-8848-5e340b28f8c7'},
#  {'@class': 'Disease',
#   '@rid': '#43:57154',
#   'alias': True,
#   'createdAt': 1612861828882,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ii pancreatic cancer ajcc v7 [c7786]',
#   'name': 'stage ii pancreatic cancer ajcc v7',
#   'out_AliasOf': ['#26:116777'],
#   'source': '#17:0',
#   'sourceId': 'c7786',
#   'updatedAt': 1612861828882,
#   'updatedBy': '#14:0',
#   'uuid': '1251ee13-bcc4-487a-a909-4d171239920d'},
#  {'@class': 'Disease',
#   '@rid': '#43:57156',
#   'alias': False,
#   'createdAt': 1612861829539,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage III includes: T4, Any N, M0. T4: Tumor involves the celiac axis or the superior mesenteric artery. M0: No distant metastasis. (AJCC 6th and 7th Eds.)',
#   'displayName': 'Stage III Pancreatic Cancer AJCC v6 and v7 [c7787]',
#   'in_AliasOf': ['#26:116798',
#    '#26:116799',
#    '#26:116800',
#    '#26:116801',
#    '#26:116802',
#    '#26:116803',
#    '#26:116804',
#    '#26:116805'],
#   'name': 'stage iii pancreatic cancer ajcc v6 and v7',
#   'out_ElementOf': ['#30:82530'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829539,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c7787',
#   'uuid': '47e257a9-7973-40ba-b680-8260db62fb52'},
#  {'@class': 'Disease',
#   '@rid': '#43:57157',
#   'alias': True,
#   'createdAt': 1612861829552,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic cancer stage iii [c7787]',
#   'name': 'pancreatic cancer stage iii',
#   'out_AliasOf': ['#26:116798'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829552,
#   'updatedBy': '#14:0',
#   'uuid': '3d33b3dd-a216-4134-ad54-b052f430ef85'},
#  {'@class': 'Disease',
#   '@rid': '#43:57160',
#   'alias': True,
#   'createdAt': 1612861829608,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c7787]',
#   'name': 'stage iii exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:116801'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829608,
#   'updatedBy': '#14:0',
#   'uuid': 'de6545ce-d5ee-4e2a-a1e9-258a39416ea4'},
#  {'@class': 'Disease',
#   '@rid': '#43:57161',
#   'alias': True,
#   'createdAt': 1612861829628,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii pancreatic cancer [c7787]',
#   'name': 'stage iii pancreatic cancer',
#   'out_AliasOf': ['#26:116802'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829628,
#   'updatedBy': '#14:0',
#   'uuid': '7ac18fe5-8bc8-4879-9520-7b5270596943'},
#  {'@class': 'Disease',
#   '@rid': '#43:57162',
#   'alias': True,
#   'createdAt': 1612861829648,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii pancreatic cancer ajcc v6 [c7787]',
#   'name': 'stage iii pancreatic cancer ajcc v6',
#   'out_AliasOf': ['#26:116803'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829648,
#   'updatedBy': '#14:0',
#   'uuid': '1b68697a-eedd-4af4-961b-ae8ac2892266'},
#  {'@class': 'Disease',
#   '@rid': '#43:57163',
#   'alias': True,
#   'createdAt': 1612861829667,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iii pancreatic cancer ajcc v7 [c7787]',
#   'name': 'stage iii pancreatic cancer ajcc v7',
#   'out_AliasOf': ['#26:116804'],
#   'source': '#17:0',
#   'sourceId': 'c7787',
#   'updatedAt': 1612861829667,
#   'updatedBy': '#14:0',
#   'uuid': 'e08bef2c-b527-4eaa-82de-b3167f4c377f'},
#  {'@class': 'Disease',
#   '@rid': '#43:59042',
#   'alias': False,
#   'createdAt': 1612862042241,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'An adenocarcinoma arising from the pancreas. It is characterized by the presence of relatively uniform malignant cells which form acinar patterns. It usually occurs during adulthood. Signs and symptoms include abdominal pain, weight loss, nausea, and diarrhea. It may metastasize to regional lymph nodes and the liver. A minority of patients develop lipase hypersecretion syndrome. This syndrome may be seen in patients with liver metastases and it is characterized by excessive secretion of lipase in the serum, polyarthralgia, and subcutaneous fat necrosis.',
#   'displayName': 'Pancreatic Acinar Cell Cancer [c7977]',
#   'in_AliasOf': ['#26:119651',
#    '#26:119652',
#    '#26:119653',
#    '#26:119654',
#    '#26:119655',
#    '#26:119656',
#    '#26:119657'],
#   'in_CrossReferenceOf': ['#28:35899'],
#   'name': 'pancreatic acinar cell cancer',
#   'source': '#17:0',
#   'sourceId': 'c7977',
#   'updatedAt': 1612862042241,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c7977',
#   'uuid': '4e298567-6ad8-423f-92b1-553f059688e8'},
#  {'@class': 'Disease',
#   '@rid': '#43:65597',
#   'alias': False,
#   'createdAt': 1612862963694,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IA includes: T1, N0, M0. T1: Tumor limited to the pancreas, 2 cm or less in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (from AJCC 7th Ed.)',
#   'displayName': 'Stage IA Pancreatic Cancer AJCC v6 and v7 [c88100]',
#   'in_AliasOf': ['#26:132642', '#26:132643'],
#   'name': 'stage ia pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c88100',
#   'updatedAt': 1612862963694,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c88100',
#   'uuid': '3ab4ce65-31ca-4127-a7d7-6ae129344e53'},
#  {'@class': 'Disease',
#   '@rid': '#43:65598',
#   'alias': True,
#   'createdAt': 1612862963706,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ia exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c88100]',
#   'name': 'stage ia exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:132642'],
#   'source': '#17:0',
#   'sourceId': 'c88100',
#   'updatedAt': 1612862963706,
#   'updatedBy': '#14:0',
#   'uuid': 'a0041521-b9fd-462b-8fac-085aa451c2dc'},
#  {'@class': 'Disease',
#   '@rid': '#43:65599',
#   'alias': True,
#   'createdAt': 1612862963725,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ia pancreatic cancer [c88100]',
#   'name': 'stage ia pancreatic cancer',
#   'out_AliasOf': ['#26:132643'],
#   'source': '#17:0',
#   'sourceId': 'c88100',
#   'updatedAt': 1612862963725,
#   'updatedBy': '#14:0',
#   'uuid': '8e91be49-2f2e-4938-bd2f-15499ed1797d'},
#  {'@class': 'Disease',
#   '@rid': '#43:65600',
#   'alias': False,
#   'createdAt': 1612862963745,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IB includes: T2, N0, M0. T2: Tumor limited to the pancreas, more than 2 cm in greatest dimension. N0: No regional lymph node metastasis. M0: No distant metastasis. (from AJCC 7th Ed.)',
#   'displayName': 'Stage IB Pancreatic Cancer AJCC v6 and v7 [c88101]',
#   'in_AliasOf': ['#26:132644', '#26:132645'],
#   'name': 'stage ib pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c88101',
#   'updatedAt': 1612862963745,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c88101',
#   'uuid': '73945d38-6abc-4fd2-8d74-b05e519067e4'},
#  {'@class': 'Disease',
#   '@rid': '#43:65601',
#   'alias': True,
#   'createdAt': 1612862963770,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ib exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c88101]',
#   'name': 'stage ib exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:132644'],
#   'source': '#17:0',
#   'sourceId': 'c88101',
#   'updatedAt': 1612862963770,
#   'updatedBy': '#14:0',
#   'uuid': 'ec8b7145-3c16-4c50-84b4-0627f02b5c2f'},
#  {'@class': 'Disease',
#   '@rid': '#43:65602',
#   'alias': True,
#   'createdAt': 1612862963789,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage ib pancreatic cancer [c88101]',
#   'name': 'stage ib pancreatic cancer',
#   'out_AliasOf': ['#26:132645'],
#   'source': '#17:0',
#   'sourceId': 'c88101',
#   'updatedAt': 1612862963789,
#   'updatedBy': '#14:0',
#   'uuid': 'b76cfb64-d82e-4eed-9113-7c214b3b6b5d'},
#  {'@class': 'Disease',
#   '@rid': '#43:65603',
#   'alias': False,
#   'createdAt': 1612862963809,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IIA includes: T3, N0, M0. T3: Tumor extends beyond the pancreas but without involvement of the celiac axis or the superior mesenteric artery. N0: No regional lymph node metastasis. M0: No distant metastasis. (from AJCC 7th Ed.)',
#   'displayName': 'Stage IIA Pancreatic Cancer AJCC v6 and v7 [c88102]',
#   'in_AliasOf': ['#26:132646', '#26:132647'],
#   'name': 'stage iia pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c88102',
#   'updatedAt': 1612862963809,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c88102',
#   'uuid': 'a6255a39-ecb3-4826-b706-d2dd70a6d2ae'},
#  {'@class': 'Disease',
#   '@rid': '#43:65604',
#   'alias': True,
#   'createdAt': 1612862963822,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iia exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c88102]',
#   'name': 'stage iia exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:132646'],
#   'source': '#17:0',
#   'sourceId': 'c88102',
#   'updatedAt': 1612862963822,
#   'updatedBy': '#14:0',
#   'uuid': '5d558430-ade8-4b32-8e43-bb4eb43bf091'},
#  {'@class': 'Disease',
#   '@rid': '#43:65605',
#   'alias': True,
#   'createdAt': 1612862963840,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iia pancreatic cancer [c88102]',
#   'name': 'stage iia pancreatic cancer',
#   'out_AliasOf': ['#26:132647'],
#   'source': '#17:0',
#   'sourceId': 'c88102',
#   'updatedAt': 1612862963840,
#   'updatedBy': '#14:0',
#   'uuid': 'e5284dfd-a357-4502-8891-8061562b0c0e'},
#  {'@class': 'Disease',
#   '@rid': '#43:65606',
#   'alias': False,
#   'createdAt': 1612862963859,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'Stage IIB includes: (T1, N1, M0); (T2, N1, M0); (T3, N1, M0). T1: Tumor limited to the pancreas, 2 cm or less in greatest dimension. T2: Tumor limited to the pancreas, more than 2 cm in greatest dimension. T3: Tumor extends beyond the pancreas but without involvement of the celiac axis or the superior mesenteric artery. N1: Regional lymph node metastasis. M0: No distant metastasis. (from AJCC 7th Ed.)',
#   'displayName': 'Stage IIB Pancreatic Cancer AJCC v6 and v7 [c88103]',
#   'in_AliasOf': ['#26:132648', '#26:132649'],
#   'name': 'stage iib pancreatic cancer ajcc v6 and v7',
#   'source': '#17:0',
#   'sourceId': 'c88103',
#   'updatedAt': 1612862963859,
#   'updatedBy': '#14:0',
#   'url': 'http://ncicb.nci.nih.gov/xml/owl/evs/thesaurus.owl#c88103',
#   'uuid': '29886648-8fc6-4f84-993a-84325e91b5d4'},
#  {'@class': 'Disease',
#   '@rid': '#43:65607',
#   'alias': True,
#   'createdAt': 1612862963871,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iib exocrine and endocrine pancreatic cancer ajcc v6 and v7 [c88103]',
#   'name': 'stage iib exocrine and endocrine pancreatic cancer ajcc v6 and v7',
#   'out_AliasOf': ['#26:132648'],
#   'source': '#17:0',
#   'sourceId': 'c88103',
#   'updatedAt': 1612862963871,
#   'updatedBy': '#14:0',
#   'uuid': 'f267e294-0951-4a70-8158-059e1df34ee7'},
#  {'@class': 'Disease',
#   '@rid': '#43:65608',
#   'alias': True,
#   'createdAt': 1612862963890,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'stage iib pancreatic cancer [c88103]',
#   'name': 'stage iib pancreatic cancer',
#   'out_AliasOf': ['#26:132649'],
#   'source': '#17:0',
#   'sourceId': 'c88103',
#   'updatedAt': 1612862963890,
#   'updatedBy': '#14:0',
#   'uuid': 'd5868188-f4d2-4a63-8ba2-c66c7007c305'},
#  {'@class': 'Disease',
#   '@rid': '#43:87371',
#   'alias': True,
#   'createdAt': 1612925655691,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'pancreatic duct cancer',
#   'name': 'pancreatic duct cancer',
#   'out_AliasOf': ['#26:153647'],
#   'source': '#17:19',
#   'sourceId': 'doid:3587',
#   'updatedAt': 1612925655691,
#   'updatedBy': '#14:0',
#   'uuid': '75c2a7f3-31ea-4f01-912b-f0daad46e3f0'},
#  {'@class': 'Disease',
#   '@rid': '#43:100463',
#   'alias': False,
#   'createdAt': 1612926226527,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'An endocrine gland cancer located_in the pancreas.',
#   'displayName': 'pancreatic cancer',
#   'in_AliasOf': ['#26:161479',
#    '#26:161480',
#    '#26:161481',
#    '#26:161482',
#    '#26:161483',
#    '#26:161484',
#    '#26:161485',
#    '#26:161486',
#    '#26:161487'],
#   'in_DeprecatedBy': ['#29:1479', '#29:1480', '#29:1481', '#29:1482'],
#   'in_SubClassOf': ['#33:1655',
#    '#33:6724',
#    '#33:6979',
#    '#33:9875',
#    '#33:10043',
#    '#33:10074',
#    '#33:10299'],
#   'name': 'pancreatic cancer',
#   'out_SubClassOf': ['#33:2894', '#33:2997'],
#   'source': '#17:19',
#   'sourceId': 'doid:1793',
#   'subsets': ['doid#topnodes_docancerslim',
#    'doid#do_rare_slim',
#    'doid#ncithesaurus',
#    'doid#do_cancer_slim'],
#   'updatedAt': 1612926226527,
#   'updatedBy': '#14:0',
#   'uuid': '76d148ff-0e81-4b1a-a3f9-43b9c01f30e7'},
#  {'@class': 'Disease',
#   '@rid': '#43:100473',
#   'alias': False,
#   'createdAt': 1612926226713,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'pancreatic cancer',
#   'name': 'pancreatic cancer',
#   'out_DeprecatedBy': ['#29:1479'],
#   'source': '#17:19',
#   'sourceId': 'doid:1797',
#   'updatedAt': 1612926226713,
#   'updatedBy': '#14:0',
#   'uuid': '4e04d9d3-b223-46cc-8aa5-5fad7db1e31b'},
#  {'@class': 'Disease',
#   '@rid': '#43:100474',
#   'alias': False,
#   'createdAt': 1612926226733,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'pancreatic cancer',
#   'name': 'pancreatic cancer',
#   'out_DeprecatedBy': ['#29:1480'],
#   'source': '#17:19',
#   'sourceId': 'doid:9859',
#   'updatedAt': 1612926226733,
#   'updatedBy': '#14:0',
#   'uuid': 'da651673-c465-42a2-9106-62f5d7865704'},
#  {'@class': 'Disease',
#   '@rid': '#43:100475',
#   'alias': False,
#   'createdAt': 1612926226753,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'pancreatic cancer',
#   'name': 'pancreatic cancer',
#   'out_DeprecatedBy': ['#29:1481'],
#   'source': '#17:19',
#   'sourceId': 'doid:3588',
#   'updatedAt': 1612926226753,
#   'updatedBy': '#14:0',
#   'uuid': 'eb20af96-5947-4186-9296-521e093c0cc8'},
#  {'@class': 'Disease',
#   '@rid': '#43:100476',
#   'alias': False,
#   'createdAt': 1612926226774,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'pancreatic cancer',
#   'name': 'pancreatic cancer',
#   'out_DeprecatedBy': ['#29:1482'],
#   'source': '#17:19',
#   'sourceId': 'doid:14356',
#   'updatedAt': 1612926226774,
#   'updatedBy': '#14:0',
#   'uuid': 'da4e4b84-146a-44b0-bd26-9fe4f8da7aaa'}]

# %% [markdown]
# The above will look for diseases that have both 'cancer' and 'pancreatic' in the name.

# %% [markdown]
# #### Subquery Filters
#
# Sometimes we would like to filter records on a linked field (essentially a foreign key). We can do this with subquery filters.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}
    },
}, paginate=False, limit=10)
# Out:
# [{'@class': 'Disease',
#   '@rid': '#43:72269',
#   'alias': True,
#   'createdAt': 1612924874193,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'von reklinghausen disease',
#   'name': 'von reklinghausen disease',
#   'out_AliasOf': ['#26:145059'],
#   'source': '#17:19',
#   'sourceId': 'doid:8712',
#   'updatedAt': 1612924874193,
#   'updatedBy': '#14:0',
#   'uuid': '5647ae2d-8837-48fd-8b46-7669ec046e8e'},
#  {'@class': 'Disease',
#   '@rid': '#43:72251',
#   'alias': True,
#   'createdAt': 1612924873047,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'other named variants of lymphosarcoma and reticulosarcoma involving lymph nodes of axilla and upper limb',
#   'name': 'other named variants of lymphosarcoma and reticulosarcoma involving lymph nodes of axilla and upper limb',
#   'out_AliasOf': ['#26:145052'],
#   'source': '#17:19',
#   'sourceId': 'doid:8716',
#   'updatedAt': 1612924873047,
#   'updatedBy': '#14:0',
#   'uuid': '9586920c-fc10-4c5d-9cdb-f92d234d7cb3'},
#  {'@class': 'Disease',
#   '@rid': '#43:72256',
#   'alias': True,
#   'createdAt': 1612924873474,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'other named variants of lymphosarcoma and reticulosarcoma involving intrapelvic lymph nodes',
#   'name': 'other named variants of lymphosarcoma and reticulosarcoma involving intrapelvic lymph nodes',
#   'out_AliasOf': ['#26:145057'],
#   'source': '#17:19',
#   'sourceId': 'doid:8716',
#   'updatedAt': 1612924873474,
#   'updatedBy': '#14:0',
#   'uuid': 'e8cf5e88-9624-4900-8986-177e607fd95a'},
#  {'@class': 'Disease',
#   '@rid': '#43:72233',
#   'alias': False,
#   'createdAt': 1612924871520,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'obsolete carcinoma in situ of respiratory system',
#   'name': 'obsolete carcinoma in situ of respiratory system',
#   'out_DeprecatedBy': ['#29:84'],
#   'source': '#17:19',
#   'sourceId': 'doid:8965',
#   'updatedAt': 1612924871520,
#   'updatedBy': '#14:0',
#   'uuid': '96b23041-6351-44ab-ae86-378f0bbe05c4'},
#  {'@class': 'Disease',
#   '@rid': '#43:72238',
#   'alias': True,
#   'createdAt': 1612924871901,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'decubitus (pressure) ulcer',
#   'name': 'decubitus (pressure) ulcer',
#   'out_AliasOf': ['#26:145044'],
#   'source': '#17:19',
#   'sourceId': 'doid:8717',
#   'updatedAt': 1612924871901,
#   'updatedBy': '#14:0',
#   'uuid': '7be15c9b-9d9e-43cd-9256-2ed14b52aa4d'},
#  {'@class': 'Disease',
#   '@rid': '#43:72261',
#   'alias': False,
#   'createdAt': 1612924873816,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'obsolete lymphosarcoma and reticulosarcoma',
#   'name': 'obsolete lymphosarcoma and reticulosarcoma',
#   'out_DeprecatedBy': ['#29:93'],
#   'source': '#17:19',
#   'sourceId': 'doid:8890',
#   'updatedAt': 1612924873816,
#   'updatedBy': '#14:0',
#   'uuid': 'cbbe1575-2256-4dee-9386-a137a0e34137'},
#  {'@class': 'Disease',
#   '@rid': '#43:72266',
#   'alias': False,
#   'createdAt': 1612924874015,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'obsolete lymphosarcoma and reticulosarcoma',
#   'name': 'obsolete lymphosarcoma and reticulosarcoma',
#   'out_DeprecatedBy': ['#29:98'],
#   'source': '#17:19',
#   'sourceId': 'doid:8764',
#   'updatedAt': 1612924874015,
#   'updatedBy': '#14:0',
#   'uuid': '0b4ebc45-dacf-4326-bd2b-c08d4d3c7d8d'},
#  {'@class': 'Disease',
#   '@rid': '#43:72243',
#   'alias': False,
#   'createdAt': 1612924872105,
#   'createdBy': '#14:0',
#   'deprecated': True,
#   'displayName': 'decubitus ulcer',
#   'name': 'decubitus ulcer',
#   'out_DeprecatedBy': ['#29:88'],
#   'source': '#17:19',
#   'sourceId': 'doid:9002',
#   'updatedAt': 1612924872105,
#   'updatedBy': '#14:0',
#   'uuid': '4f370f02-3f82-4031-84a6-52596ce369b5'},
#  {'@class': 'Disease',
#   '@rid': '#43:72248',
#   'alias': True,
#   'createdAt': 1612924872811,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'other named variants of lymphosarcoma and reticulosarcoma involving intra-abdominal lymph nodes',
#   'name': 'other named variants of lymphosarcoma and reticulosarcoma involving intra-abdominal lymph nodes',
#   'out_AliasOf': ['#26:145049'],
#   'source': '#17:19',
#   'sourceId': 'doid:8716',
#   'updatedAt': 1612924872811,
#   'updatedBy': '#14:0',
#   'uuid': '4eff8478-f029-4481-926d-6d3ad53550ea'},
#  {'@class': 'Disease',
#   '@rid': '#43:72244',
#   'alias': False,
#   'createdAt': 1612924872155,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'displayName': 'obsolete lymphosarcoma and reticulosarcoma',
#   'in_AliasOf': ['#26:145046',
#    '#26:145047',
#    '#26:145048',
#    '#26:145049',
#    '#26:145050',
#    '#26:145051',
#    '#26:145052',
#    '#26:145053',
#    '#26:145054',
#    '#26:145055',
#    '#26:145056',
#    '#26:145057'],
#   'in_DeprecatedBy': ['#29:89',
#    '#29:90',
#    '#29:91',
#    '#29:92',
#    '#29:93',
#    '#29:94',
#    '#29:95',
#    '#29:96',
#    '#29:97',
#    '#29:98'],
#   'name': 'obsolete lymphosarcoma and reticulosarcoma',
#   'source': '#17:19',
#   'sourceId': 'doid:8716',
#   'subsets': [],
#   'updatedAt': 1612924872155,
#   'updatedBy': '#14:0',
#   'uuid': '9af84b66-edc3-4a86-8e90-e81abade2693'}]

# %% [markdown]
# Above we are only returning disease records that have been imported from the disease ontology.

# %% [markdown]
# ### Return Properties (Fields)
#
# The return fields property allows the user to specify what they would like to return. This can mean returning a subset of fields for a large query to improve the speed of the client digesting the data, or it can be used to de-nest fields. By default the query will return only the immediate properties of the class being queries. This means that linked fields will be listed as their record ID. De-nesting these fields allows you to return them without additional queries.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
})
# Out:
# [{'@class': 'Disease',
#   '@rid': '#43:100548',
#   'alias': False,
#   'createdAt': 1612926228848,
#   'createdBy': '#14:0',
#   'deprecated': False,
#   'description': 'A disease of cellular proliferation that is malignant and primary, characterized by uncontrolled cellular proliferation, local cell invasion and metastasis.',
#   'displayName': 'cancer',
#   'history': '#43:107678',
#   'in_AliasOf': ['#26:161531', '#26:161532', '#26:161533'],
#   'in_SubClassOf': ['#33:5210', '#33:5268'],
#   'name': 'cancer',
#   'out_CrossReferenceOf': ['#28:37957'],
#   'out_ElementOf': ['#30:82543'],
#   'out_SubClassOf': ['#33:7594'],
#   'source': '#17:19',
#   'sourceId': 'doid:162',
#   'subsets': ['doid#do_flybase_slim',
#    'doid#ncithesaurus',
#    'doid#do_cancer_slim',
#    'doid#do_agr_slim',
#    'doid#do_gxd_slim'],
#   'updatedAt': 1612980640268,
#   'updatedBy': '#14:0',
#   'uuid': '6a051270-4611-4af2-a5ff-1b31a872b4e0'}]

# %% [markdown]
# We probably are not interested in all of these fields so let's pick a few to return.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
    'returnProperties': ['name', 'source', 'sourceId', 'alias', 'deprecated']
})
# Out:
# [{'alias': False,
#   'deprecated': False,
#   'name': 'cancer',
#   'source': '#17:19',
#   'sourceId': 'doid:162'}]

# %% [markdown]
# The new return looks much more reasonable. However the source field right now is a seperate record ID. This means with the current query we would have to fetch that record separately if we want to see details about it. This can be done in a single query with the nested return properties. Simply delimite properties and sub-properties with a period.

# %%
graphkb_conn.query({
    'target': 'Disease',
    'filters': {
        'AND': [
            {'source': {'target': 'Source', 'filters': {'name': 'disease ontology'}}},
            {'name': 'cancer'}
        ],
    },
    'returnProperties': ['name', 'source.name', 'sourceId', 'alias', 'deprecated']
})
# Out:
# [{'alias': False,
#   'deprecated': False,
#   'name': 'cancer',
#   'source': {'name': 'disease ontology'},
#   'sourceId': 'doid:162'}]
