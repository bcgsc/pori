# %% [markdown]
# # Annotate a VCF with GraphKB

# %% [markdown]
# <a href="https://colab.research.google.com/github/bcgsc/pori/blob/feature%2Fcolab-notebooks/docs/graphkb/scripting/Annotate_a_VCF_with_GraphKB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# A common format for small mutations is the VCF file. There are a number of variants of this format. To help users getting started we have provided this example script of how to convert from a VCF file to the JSON format that the python adapter requires.
#
# We expect users to annotate their VCF files with protein and/or cds HGVS notation prior to this.

# %% [markdown]
# ## Download Files

# %% [markdown]
# ## Install
#
# To do this we are going to install a couple of common python libraries. We will use pysam to read the vcf file ([Pysam - Working with VCF](https://pysam.readthedocs.io/en/latest/usage.html#working-with-vcf-bcf-formatted-files)).

# %%
# %pip install pysam pandas seaborn pori_python
# Out:
# Requirement already satisfied: pysam in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (0.23.3)
# Requirement already satisfied: pandas in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: seaborn in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: pori_python in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.23.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: biopython in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (1.85)
# Requirement already satisfied: jsonschema in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.25.1)
# Requirement already satisfied: requests in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (2.32.5)
# Requirement already satisfied: tqdm in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.67.1)
# Requirement already satisfied: typing_extensions<5,>=3.7.4.2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from pori_python) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: six>=1.5 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: attrs>=22.2.0 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from jsonschema->pori_python) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /projects/dat/workspace/mlemieux/projects/pori/pori_/venv/lib/python3.11/site-packages (from requests->pori_python) (2025.10.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Prepare Canonical Transcripts List
#
# First we will read the tabbed biomart export file. This contains a list of gene and transcript IDs for only canonical transcripts. We'll use this to filter annotations in a later step

# %%
import pandas as pd 

mart_df = pd.read_csv('https://raw.githubusercontent.com/bcgsc/pori/feature/colab-notebooks/demo/mart_export.protein_coding.canonical.txt', sep='\t')
mart_df
# Out:
#       Gene stable ID version Transcript stable ID version
# 0          ENSG00000198888.2            ENST00000361390.2
# 1          ENSG00000198763.3            ENST00000361453.3
# 2          ENSG00000198804.2            ENST00000361624.2
# 3          ENSG00000198712.1            ENST00000361739.1
# 4          ENSG00000228253.1            ENST00000361851.1
# ...                      ...                          ...
# 22791      ENSG00000181817.6            ENST00000315732.3
# 22792     ENSG00000116885.18            ENST00000235532.9
# 22793     ENSG00000116898.12            ENST00000373116.6
# 22794     ENSG00000119535.18            ENST00000373106.6
# 22795      ENSG00000142694.7            ENST00000490466.2
#
# [22796 rows x 2 columns]

# %% [markdown]
# In this case we know that the transcripts in our VCF are unversioned so we will store the transcript names without their versions as well for quick access in later steps

# %%
mart_df['unversioned'] = mart_df['Transcript stable ID version'].str.split('.').str[0]
canonical_transcripts = set(mart_df['Transcript stable ID version'].unique().tolist() + mart_df['unversioned'].unique().tolist())
len(canonical_transcripts)
# Out:
# 45592

# %% [markdown]
# ## Process the VCF
#
# Then we are ready to read the VCF file as input

# %%
# !wget https://raw.githubusercontent.com/bcgsc/pori/feature/colab-notebooks/demo/example_snvs.variants.passed.4.3.eff.hgvs.vcf
# Out:
# --2025-10-07 09:44:28--  https://raw.githubusercontent.com/bcgsc/pori/feature/colab-notebooks/demo/example_snvs.variants.passed.4.3.eff.hgvs.vcf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 387417 (378K) [text/plain]
# Saving to: ‘example_snvs.variants.passed.4.3.eff.hgvs.vcf.1’
#
# example_snvs.varian 100%[===================>] 378.34K  --.-KB/s    in 0.009s
#
# 2025-10-07 09:44:28 (41.0 MB/s) - ‘example_snvs.variants.passed.4.3.eff.hgvs.vcf.1’ saved [387417/387417]

# %%
from pysam import VariantFile

fh = VariantFile('./example_snvs.variants.passed.4.3.eff.hgvs.vcf')

# %% [markdown]
# Then we will iterate over the variant VCF records. From here we will need to pull out the HGVSp notation. Since this is output from SnpEff we can refer to their [documentation](https://pcingola.github.io/SnpEff/se_inputoutput/#eff-field-vcf-output-files) for how to parse this. According to their site this is the expected format of the `EFF` field which contains the HGVS notation. This field is pipe delimited inside parentheses.
#
# ```text
# EFF= Effect ( Effect_Impact | Functional_Class | Codon_Change | Amino_Acid_Change| Amino_Acid_Length | Gene_Name | Transcript_BioType | Gene_Coding | Transcript_ID | Exon_Rank  | Genotype_Number [ | ERRORS | WARNINGS ] )
# ```
#
# **Note**: EFF is a deprecated field. Newer versions use the `ANN` field. Parsing should be similar.
#
# We define the following functions below to help with parsing the INFO fields in the VCF

# %%
import re 


def parse_eff(eff):
  match = re.match(r'^[^(]+\((.+)\)$', eff)
  if match:
    [impact, functional_class, codon_change, aa_change, _, gene_name, transcript_biotype, gene_coding, transcript_id, _, genotype_allele ] = match.group(1).split('|')[:11]

    changes = aa_change.split('/')
    protein_changes = [p for p in changes if p.startswith('p.')]
    cds_changes = [p for p in changes if p.startswith('c.')]
    
    return [
      impact, 
      gene_name,
      transcript_biotype,
      gene_coding, 
      transcript_id, 
      protein_changes[0] if protein_changes else None, 
      cds_changes[0] if cds_changes else None,
      genotype_allele
    ]
  raise NotImplementedError('cannot parse eff string. Does not match the expected pattern')

# %% [markdown]
# Now we want to convert the parsed content into a JSON/Dict to match the fields that we expect in IPR. If you are not uploading to IPR you can leave variants in their original format instead.
#
# **Note**: Some of the fields (support counts) require picking the samples. By default we have assumed the names are NORMAL and TUMOR. These may need to be customized for other input

# %%
from pori_python.graphkb.util import convert_aa_3to1


def pick_effect(record):
  non_canonical = []

  for eff in record.info['EFF']:
    [impact, gene_name, transcript_biotype, gene_coding, transcript_id, protein_change, cds_change, alt_allele] = parse_eff(eff)
    
    # prefer canonical annotation
    if transcript_id in canonical_transcripts:
      return [impact, gene_name, transcript_biotype, gene_coding, transcript_id, protein_change, cds_change, alt_allele]
    non_canonical.append([impact, gene_name, transcript_biotype, gene_coding, transcript_id, protein_change, cds_change, alt_allele])
      
  return non_canonical[0]



ipr_variants = []

for record in fh.fetch():
  tumour_sample = record.samples['TUMOR']
  normal_sample = record.samples['NORMAL']
  ref_key = f'{record.ref}U'

  no_canonical = True

  [impact, gene_name, transcript_biotype, gene_coding, transcript_id, protein_change, cds_change, alt_allele] = pick_effect(record)



  alt_key = f'{alt_allele}U'
  if protein_change:
    protein_change = convert_aa_3to1(protein_change)
  

  # convert variant string from 3 to 1 letter AA if it is protein notation
  ipr_format = {
      'gene': gene_name,
      'transcript': transcript_id,
      'chromosome': record.chrom,
      'startPosition': record.pos,
      'endPosition': record.pos + record.rlen,
      'proteinChange': protein_change or cds_change,  # if no protein change use cds here instead
      'refSeq': record.ref,
      'altSeq': alt_allele,
      'tumourDepth': tumour_sample['DP'],
      'normalDepth': normal_sample['DP'],
      'normalRefCount': normal_sample[ref_key],
      'normalAltCount': normal_sample[alt_key],
      'tumourRefCount': tumour_sample[ref_key],
      'tumourAltCount': tumour_sample[alt_key],
      'hgvsProtein': f'{gene_name}:{protein_change}' if protein_change else '',
      'hgvsCds': f'{transcript_id}:{cds_change}' if cds_change else ''
  }
  ipr_variants.append(ipr_format)

# just for displaying in notebook
variants_df = pd.DataFrame.from_records(ipr_variants)
variants_df
# Out:
#            gene       transcript chromosome  startPosition  endPosition  \
# 0         NOC2L  ENST00000327044          1         883516       883517
# 1        ATAD3B  ENST00000378741          1        1418472      1418473
# 2        PRDM16  ENST00000270722          1        3329312      3329313
# 3       TNFRSF8  ENST00000263932          1       12170228     12170229
# 4        CLCNKB  ENST00000375679          1       16372084     16372085
# ..          ...              ...        ...            ...          ...
# 410     ZNF280C  ENST00000370978          X      129362963    129362964
# 411     ZNF280C  ENST00000370978          X      129362964    129362965
# 412       PNMA3  ENST00000370264          X      152226437    152226438
# 413      WASH6P  ENST00000359512          X      155253820    155253821
# 414  AC134882.1  ENST00000331172          Y       13524548     13524549
#
#     proteinChange refSeq altSeq  tumourDepth  normalDepth normalRefCount  \
# 0         p.L552L      G      A           69           44       (42, 45)
# 1         p.R114*      A      T           41           33       (31, 33)
# 2         p.P851S      C      T           52           49       (47, 49)
# 3         p.P215S      C      T           57           26       (24, 27)
# 4          p.F44F      C      T           70           51       (51, 52)
# ..            ...    ...    ...          ...          ...            ...
# 410       p.H379Y      G      A           40           19       (19, 21)
# 411       p.P378P      G      A           40           19       (19, 21)
# 412       p.P342L      C      T           60           28       (28, 32)
# 413       p.G373S      G      A           74           40       (39, 59)
# 414        p.Y57S      T      G           15           15       (13, 13)
#
#     normalAltCount tumourRefCount tumourAltCount        hgvsProtein  \
# 0           (0, 0)       (16, 16)       (53, 56)      NOC2L:p.L552L
# 1           (0, 0)       (29, 34)       (10, 14)     ATAD3B:p.R114*
# 2           (2, 2)       (40, 44)       (10, 10)     PRDM16:p.P851S
# 3           (0, 1)       (12, 12)       (43, 44)    TNFRSF8:p.P215S
# 4           (0, 0)       (50, 51)       (18, 19)      CLCNKB:p.F44F
# ..             ...            ...            ...                ...
# 410         (0, 0)         (0, 0)       (39, 42)    ZNF280C:p.H379Y
# 411         (0, 0)         (0, 1)       (39, 41)    ZNF280C:p.P378P
# 412         (0, 0)         (0, 1)       (57, 61)      PNMA3:p.P342L
# 413         (0, 1)      (61, 114)        (9, 20)     WASH6P:p.G373S
# 414         (2, 3)         (0, 0)       (14, 26)  AC134882.1:p.Y57S
#
#                        hgvsCds
# 0    ENST00000327044:c.1654C>T
# 1     ENST00000378741:c.340A>T
# 2    ENST00000270722:c.2551C>T
# 3     ENST00000263932:c.643C>T
# 4     ENST00000375679:c.132C>T
# ..                         ...
# 410  ENST00000370978:c.1135C>T
# 411  ENST00000370978:c.1134C>T
# 412  ENST00000370264:c.1025C>T
# 413  ENST00000359512:c.1117G>A
# 414   ENST00000331172:c.170A>C
#
# [415 rows x 16 columns]

# %% [markdown]
# Optionnaly, save in a tab-delimited file so variants can be annotate later. Can serve as input file for the [annotate_snpsift.py](./annotate_snpsift.py) script.

# %%
variants_df.to_csv('variants.tsv', sep='\t', index=False)

# %% [markdown]
# ## Annotate
#
# Now we are ready to add GraphKB annotations. First connect to the API. Here we are using the demo credentials.
#
# If you were uploading to IPR you would skip this step and just input the variants since the python adapter performs matching against GraphKB prior to uploading the report.
#
# **NOTE**: The demo server is incomplete. It contains a small subset of the data we would expect in a normal production instance of GraphKB and should be used for demonstration and testing only

# %%
from pori_python.graphkb import GraphKBConnection
import os

GKB_API_URL = 'https://graphkbdev-api.bcgsc.ca/api' # 'https://pori-demo.bcgsc.ca/graphkb-api/api'
GKB_USER = os.environ.get('USER') # 'colab_demo'
GKB_PASSWORD = os.environ.get('JIRA_PASS') # 'colab_demo'

graphkb_conn = GraphKBConnection(GKB_API_URL, use_global_cache=False)

graphkb_conn.login(GKB_USER, GKB_PASSWORD)

# %% [markdown]
# Now use the matching functions to get the equivalent variant forms from GraphKB. This may take several minutes on the demo server as it has limited resources and open access.

# %%
from pori_python.graphkb.match import match_positional_variant
from pori_python.graphkb.util import FeatureNotFoundError

for variant in ipr_variants:
  # for the purposes of this tutorial we will skip non-protein changes for now
  if not variant['hgvsProtein']:
    continue
  variant_name = variant['gene'] + ':' + variant['proteinChange']
  try:
    variant_matches = match_positional_variant(graphkb_conn, variant_name)
    variant['_variantMatches'] = variant_matches
    if variant_matches:
      print(f'{variant_name} matched {len(variant_matches)} other variant representations')
  except FeatureNotFoundError:
    pass # if the gene isn't in the db, there will not be annotations
  except Exception as err:
    print(variant_name, err)

print(f'queried {len(ipr_variants)} variants')
# Out:
# SF3B1:p.P718L matched 2 other variant representations
# ATR:p.L2064L matched 2 other variant representations
# TNPO1:p.Q38H matched 1 other variant representations
# STK19:p.D89N matched 9 other variant representations
# NOTCH4:p.Y752N matched 1 other variant representations
# HDAC2:p.R409* matched 1 other variant representations
# BRAF:p.V600E matched 29 other variant representations
# GPR124:p.E863K matched 1 other variant representations
# PCSK5:p.C747Y matched 1 other variant representations
# ANK3:p.G74G matched 1 other variant representations
# AHNAK:p.D4413D matched 1 other variant representations
# GLI1:p.S1094F matched 7 other variant representations
# PABPC3:p.G234R matched 1 other variant representations
# RAD51B:p.R385K matched 3 other variant representations
# MAP4K1:p.P298P matched 1 other variant representations
# queried 415 variants

# %% [markdown]
# Now that we have matched the variant we will fetch the related statements to annotate this variant with its possible relevance

# %%
from pori_python.graphkb.constants import FAILED_REVIEW_STATUS, STATEMENT_RETURN_PROPERTIES
from pori_python.graphkb.util import convert_to_rid_list

results = []

for variant in ipr_variants:
  if not variant.get('_variantMatches'):
    continue
  variant_name = variant['gene'] + ':' + variant['proteinChange']
  variant_matches = variant['_variantMatches']
  statements = graphkb_conn.query(
      {
          'target': 'Statement',
          'filters': {'conditions': convert_to_rid_list(variant_matches), 'operator': 'CONTAINSANY'},
          'returnProperties': STATEMENT_RETURN_PROPERTIES, # should be customized to the users needs
      }
  )

  # filtering out statements with failed review
  statements = [s for s in statements if s.get("reviewStatus") != FAILED_REVIEW_STATUS]

  print(variant_name)
  print(f'annotated {len(variant_matches)} variant matches with {len(statements)} statements')
  print()

  for statement in statements:
      results.append((
          variant_name, 
          len(variant_matches), 
          ';'.join([c['displayName'] for c in statement['conditions'] if c['@class'].endswith('Variant')]),
          statement['relevance']['displayName'],
          statement['subject']['displayName'],
          statement['source']['displayName'] if statement['source'] else '',
          ';'.join([c['displayName'] for c in statement['evidence']])
      ))
# Out:
# SF3B1:p.P718L
# annotated 2 variant matches with 6 statements
#
# ATR:p.L2064L
# annotated 2 variant matches with 5 statements
#
# TNPO1:p.Q38H
# annotated 1 variant matches with 0 statements
#
# STK19:p.D89N
# annotated 9 variant matches with 2 statements
#
# NOTCH4:p.Y752N
# annotated 1 variant matches with 0 statements
#
# HDAC2:p.R409*
# annotated 1 variant matches with 1 statements
#
# BRAF:p.V600E
# annotated 29 variant matches with 331 statements
#
# GPR124:p.E863K
# annotated 1 variant matches with 0 statements
#
# PCSK5:p.C747Y
# annotated 1 variant matches with 0 statements
#
# ANK3:p.G74G
# annotated 1 variant matches with 0 statements
#
# AHNAK:p.D4413D
# annotated 1 variant matches with 0 statements
#
# GLI1:p.S1094F
# annotated 7 variant matches with 0 statements
#
# PABPC3:p.G234R
# annotated 1 variant matches with 0 statements
#
# RAD51B:p.R385K
# annotated 3 variant matches with 3 statements
#
# MAP4K1:p.P298P
# annotated 1 variant matches with 0 statements

# %% [markdown]
# Now we will put this into a dataframe to display nicely in this notebook

# %%
df = pd.DataFrame(results, columns=['variant_name', 'variant_matches', 'statement_variants', 'relevance', 'subject', 'statement_source', 'evidence'])
df
# Out:
#        variant_name  variant_matches statement_variants  \
# 0     SF3B1:p.P718L                2     SF3B1 mutation
# 1     SF3B1:p.P718L                2     SF3B1 mutation
# 2     SF3B1:p.P718L                2     SF3B1 mutation
# 3     SF3B1:p.P718L                2     SF3B1 mutation
# 4     SF3B1:p.P718L                2     SF3B1 mutation
# ..              ...              ...                ...
# 343    BRAF:p.V600E               29        BRAF:p.V600
# 344    BRAF:p.V600E               29        BRAF:p.V600
# 345  RAD51B:p.R385K                3    RAD51B mutation
# 346  RAD51B:p.R385K                3    RAD51B mutation
# 347  RAD51B:p.R385K                3    RAD51B mutation
#
#                   relevance  \
# 0      favourable prognosis
# 1    unfavourable prognosis
# 2    unfavourable prognosis
# 3    unfavourable prognosis
# 4    unfavourable prognosis
# ..                      ...
# 343             sensitivity
# 344              resistance
# 345             sensitivity
# 346             eligibility
# 347             sensitivity
#
#                                                subject statement_source  \
# 0                                              patient            CIViC
# 1                                              patient            CIViC
# 2                                              patient            CIViC
# 3                                              patient            CIViC
# 4                                              patient            CIViC
# ..                                                 ...              ...
# 343                            dabrafenib + trametinib            CIViC
# 344                                Panitumumab [c1857]            CIViC
# 345                                 olaparib [DB09074]        MOAlmanac
# 346  A Randomized, 2-cohort, Double-blind, Placebo-...
# 347                                  Olaparib [c71721]            CIViC
#
#                                               evidence
# 0                                        pmid:21995386
# 1                                        pmid:26837699
# 2                                        pmid:24943832
# 3                                        pmid:23086750
# 4                                        pmid:23568491
# ..                                                 ...
# 343                                      pmid:23020132
# 344                                      pmid:23325582
# 345                                   MOAlmanac FDA-58
# 346  A Randomized, 2-cohort, Double-blind, Placebo-...
# 347                                      pmid:32343890
#
# [348 rows x 7 columns]
